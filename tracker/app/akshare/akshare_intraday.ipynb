# %% [markdown]
# ## 实时行情数据
# ### 实时行情数据-东财

# %% [markdown]
# 沪深京 A 股

# %%
import akshare as ak

stock_zh_a_spot_em_df = ak.stock_zh_a_spot_em()
stock_zh_a_spot_em_df
# Out:
#   0%|          | 0/57 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 3
#       1 import akshare as ak
# ----> 3 stock_zh_a_spot_em_df = ak.stock_zh_a_spot_em()
#       4 stock_zh_a_spot_em_df
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/stock_feature/stock_hist_em.py:36, in stock_zh_a_spot_em()
#      22 url = "https://82.push2.eastmoney.com/api/qt/clist/get"
#      23 params = {
#      24     "pn": "1",
#      25     "pz": "100",
#    (...)     34               "f20,f21,f23,f24,f25,f22,f11,f62,f128,f136,f115,f152",
#      35 }
# ---> 36 temp_df = fetch_paginated_data(url, params)
#      37 temp_df.columns = [
#      38     "index",
#      39     "_",
#    (...)     69     "-",
#      70 ]
#      71 temp_df.rename(columns={"index": "序号"}, inplace=True)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/utils/func.py:46, in fetch_paginated_data(url, base_params, timeout)
#      44 for page in tqdm(range(2, total_page + 1), leave=False):
#      45     params.update({"pn": page})
# ---> 46     r = requests.get(url, params=params, timeout=timeout)
#      47     data_json = r.json()
#      48     inner_temp_df = pd.DataFrame(data_json["data"]["diff"])
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)    678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# 沪 A 股

# %%
stock_sh_a_spot_em_df = ak.stock_sh_a_spot_em()
stock_sh_a_spot_em_df
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 stock_sh_a_spot_em_df = ak.stock_sh_a_spot_em()
#       2 stock_sh_a_spot_em_df
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/stock_feature/stock_hist_em.py:145, in stock_sh_a_spot_em()
#     131 url = "https://82.push2.eastmoney.com/api/qt/clist/get"
#     132 params = {
#     133     "pn": "1",
#     134     "pz": "100",
#    (...)    143               "f24,f25,f22,f11,f62,f128,f136,f115,f152",
#     144 }
# --> 145 temp_df = fetch_paginated_data(url, params)
#     146 temp_df.columns = [
#     147     "序号",
#     148     "_",
#    (...)    178     "-",
#     179 ]
#     180 temp_df = temp_df[
#     181     [
#     182         "序号",
#    (...)    205     ]
#     206 ]
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/utils/func.py:32, in fetch_paginated_data(url, base_params, timeout)
#      30 params = base_params.copy()
#      31 # 获取第一页数据，用于确定分页信息
# ---> 32 r = requests.get(url, params=params, timeout=timeout)
#      33 data_json = r.json()
#      34 # 计算分页信息
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)    678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# 深 A 股

# %%
import akshare as ak

stock_sz_a_spot_em_df = ak.stock_sz_a_spot_em()
stock_sz_a_spot_em_df
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
#         序号      代码      名称     最新价     涨跌幅     涨跌额       成交量           成交额  \
# 0        1  301629     N矽电  165.29  216.16  113.01   67345.0  1.212331e+09
# 1        2  300697    电工合金   17.34   20.00    2.89  429814.0  7.186637e+08
# 2        3  301055     张小泉   19.04   19.97    3.17   77777.0  1.436424e+08
# 3        4  301025    读客文化   10.94   19.96    1.82  357175.0  3.690430e+08
# 4        5  300721    怡达股份   17.55   14.48    2.22  436420.0  7.184069e+08
# ...    ...     ...     ...     ...     ...     ...       ...           ...
# 3026  3027  000018    神城A退     NaN     NaN     NaN       NaN           NaN
# 3027  3028  000015   PT中浩A     NaN     NaN     NaN       NaN           NaN
# 3028  3029  000013  *ST石化A     NaN     NaN     NaN       NaN           NaN
# 3029  3030  000005    ST星源     NaN     NaN     NaN       NaN           NaN
# 3030  3031  000003   PT金田A     NaN     NaN     NaN       NaN           NaN
#
#          振幅      最高  ...    量比    换手率  市盈率-动态   市净率           总市值  \
# 0     47.76  189.99  ...   NaN  64.56   74.33  5.84  6.897101e+09
# 1     12.39   17.34  ...  3.34  16.87   44.16  5.14  5.770752e+09
# 2     18.27   19.04  ...  3.00   4.99  129.51  4.74  2.970240e+09
# 3     20.83   10.94  ...  9.77  13.72  218.00  7.01  4.379385e+09
# 4     18.07   18.15  ...  4.83  31.82  150.40  2.37  2.893060e+09
# ...     ...     ...  ...   ...    ...     ...   ...           ...
# 3026    NaN     NaN  ...   NaN   0.00     NaN   NaN           NaN
# 3027    NaN     NaN  ...   NaN   0.00     NaN   NaN           NaN
# 3028    NaN     NaN  ...   NaN   0.00     NaN   NaN           NaN
# 3029    NaN     NaN  ...   NaN   0.00     NaN   NaN           NaN
# 3030    NaN     NaN  ...   NaN   0.00     NaN   NaN           NaN
#
#               流通市值    涨速  5分钟涨跌  60日涨跌幅  年初至今涨跌幅
# 0     1.724275e+09 -1.02  -1.82  216.16   216.16
# 1     4.418232e+09  0.00   0.00   50.26    37.51
# 2     2.970240e+09  0.00   0.00   14.49    20.28
# 3     2.847228e+09  0.00   0.00   -6.17    14.80
# 4     2.407173e+09 -0.40  -1.13   31.46    44.09
# ...            ...   ...    ...     ...      ...
# 3026           NaN   NaN    NaN    0.00     0.00
# 3027           NaN   NaN    NaN    0.00     0.00
# 3028           NaN   NaN    NaN    0.00     0.00
# 3029           NaN   NaN    NaN    0.00     0.00
# 3030           NaN   NaN    NaN    0.00     0.00
#
# [3031 rows x 23 columns]

# %% [markdown]
# ### 实时行情数据-新浪

# %%
import akshare as ak

stock_zh_a_spot_df = ak.stock_zh_a_spot()
stock_zh_a_spot_df
# Out:
# Please wait for a moment:   0%|          | 0/69 [00:00<?, ?it/s]
#             代码     名称     最新价    涨跌额     涨跌幅      买入      卖出      昨收      今开  \
# 0     bj920000   安徽凤凰   19.35  -0.94  -4.633   19.34   19.35   20.29   20.00
# 1     bj920001   纬达光电   18.99  -0.92  -4.621   18.99   19.00   19.91   19.70
# 2     bj920002   万达轴承  104.69   2.29   2.236  104.69  104.70  102.40  102.00
# 3     bj920003   中诚咨询   33.70  -0.12  -0.355   33.69   33.70   33.82   33.50
# 4     bj920005  XD鼎佳精   42.52  -1.55  -3.517   42.51   42.52   44.07   44.29
# ...        ...    ...     ...    ...     ...     ...     ...     ...     ...
# 5446  sz301662   宏工科技  122.30 -19.78 -13.922  122.29  122.30  142.08  137.21
# 5447  sz301665   泰禾股份   30.21  -1.46  -4.610   30.21   30.22   31.67   31.60
# 5448  sz301668   昊创瑞通   49.05  -3.24  -6.196   49.05   49.06   52.29   51.72
# 5449  sz301678    新恒汇   62.30  -3.16  -4.827   62.30   62.36   65.46   64.29
# 5450  sz302132   中航成飞   79.80  -1.17  -1.445   79.79   79.80   80.97   80.01
#
#           最高      最低         成交量          成交额       时间戳
# 0      20.31   19.33   1407160.0   27617293.0  15:13:58
# 1      19.86   18.82   1647723.0   31587282.0  15:13:58
# 2     109.60  101.21   1641918.0  172920163.0  15:13:58
# 3      34.88   33.40   2246515.0   76435887.0  15:13:58
# 4      44.29   42.44    466085.0   20022359.0  15:13:58
# ...      ...     ...         ...          ...       ...
# 5446  140.80  122.18   2936584.0  376411042.0  15:14:15
# 5447   32.03   30.15   3698347.0  113373109.0  15:13:30
# 5448   52.05   49.01   2877234.0  143851918.0  15:13:45
# 5449   64.96   61.55   2966068.0  188116348.0  15:14:00
# 5450   82.48   79.50  10581693.0  854400303.0  15:14:15
#
# [5451 rows x 14 columns]

# %% [markdown]
# ## 历史行情数据
# ### 历史行情数据-东财

# %%
stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20250324", end_date='20240324', adjust="")
stock_zh_a_hist_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 分时数据-新浪

# %%
import akshare as ak

stock_zh_a_minute_df = ak.stock_zh_a_minute(symbol='sh600751', period='1', adjust="qfq")
stock_zh_a_minute_df
# Out:
#                       day  open  high   low  close  volume
# 0     2025-11-11 13:53:00  5.04  5.06  5.04   5.05  230600
# 1     2025-11-11 13:54:00  5.06  5.06  5.04   5.05  228500
# 2     2025-11-11 13:55:00  5.05  5.06  5.05   5.06  347000
# 3     2025-11-11 13:56:00  5.05  5.06  5.04   5.04  164400
# 4     2025-11-11 13:57:00  5.05  5.05  5.04   5.04  213000
# ...                   ...   ...   ...   ...    ...     ...
# 1965  2025-11-21 14:54:00   NaN   NaN   NaN    NaN  853400
# 1966  2025-11-21 14:55:00   NaN   NaN   NaN    NaN  845400
# 1967  2025-11-21 14:56:00   NaN   NaN   NaN    NaN  317600
# 1968  2025-11-21 14:57:00   NaN   NaN   NaN    NaN  713200
# 1969  2025-11-21 15:00:00   NaN   NaN   NaN    NaN  512400
#
# [1970 rows x 6 columns]

# %% [markdown]
# ### 分时数据-东财

# %%
import akshare as ak

# 注意：该接口返回的数据只有最近一个交易日的有开盘价，其他日期开盘价为 0
stock_zh_a_hist_min_em_df = ak.stock_zh_a_hist_min_em(symbol="000001", start_date="2025-03-24 13:30:00", end_date="2024-03-24 15:00:00", period="1", adjust="")
stock_zh_a_hist_min_em_df
# Out:
# Empty DataFrame
# Columns: [时间, 开盘, 收盘, 最高, 最低, 成交量, 成交额, 均价]
# Index: []

# %% [markdown]
# ### 日内分时数据-东财

# %%
import akshare as ak

stock_intraday_em_df = ak.stock_intraday_em(symbol="000001")
stock_intraday_em_df
# Out:
#             时间    成交价     手数 买卖盘性质
# 0     09:15:00  11.85     41   中性盘
# 1     09:15:09  11.82   1367   中性盘
# 2     09:15:18  11.82   1597   中性盘
# 3     09:15:27  11.82   1603   中性盘
# 4     09:15:36  11.82   1633   中性盘
# ...        ...    ...    ...   ...
# 4666  14:56:51  11.67     47    卖盘
# 4667  14:56:54  11.67    116    卖盘
# 4668  14:56:57  11.67    116    卖盘
# 4669  14:57:00  11.67     39    卖盘
# 4670  15:00:00  11.69  17456    卖盘
#
# [4671 rows x 4 columns]

# %%
stock_intraday_em_df = ak.stock_intraday_em(symbol="603958")
stock_intraday_em_df
# Out:
#             时间    成交价   手数 买卖盘性质
# 0     09:15:16  16.30   45   中性盘
# 1     09:15:49  16.30   45   中性盘
# 2     09:15:58  16.30   52   中性盘
# 3     09:16:01  16.30   52   中性盘
# 4     09:16:19  16.30   58   中性盘
# ...        ...    ...  ...   ...
# 1864  14:56:40  15.28   26    卖盘
# 1865  14:56:43  15.28   12    卖盘
# 1866  14:56:46  15.28   99    卖盘
# 1867  14:56:49  15.28    9    卖盘
# 1868  15:00:00  15.27  247    卖盘
#
# [1869 rows x 4 columns]

# %% [markdown]
# ### 日内分时数据-新浪

# %% [markdown]
# kind	object	D 表示卖盘，U表示 是买盘

# %%
import akshare as ak

stock_intraday_sina_df = ak.stock_intraday_sina(symbol="sz000001", date="20250324")
stock_intraday_sina_df
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[7], line 3
#       1 import akshare as ak
# ----> 3 stock_intraday_sina_df = ak.stock_intraday_sina(symbol="sz000001", date="20250324")
#       4 stock_intraday_sina_df
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/stock/stock_intraday_sina.py:48, in stock_intraday_sina(symbol, date)
#      42 headers = {
#      43     "Referer": f"https://vip.stock.finance.sina.com.cn/quotes_service/view/cn_bill.php?symbol={symbol}",
#      44     "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) "
#      45     "Chrome/107.0.0.0 Safari/537.36",
#      46 }
#      47 r = requests.get(url=url, params=params, headers=headers)
# ---> 48 data_json = r.json()
#      49 total_page = math.ceil(int(data_json) / 60)
#      50 url = "https://vip.stock.finance.sina.com.cn/quotes_service/api/json_v2.php/CN_Bill.GetBillList"
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ### 盘前数据

# %%
import akshare as ak

stock_zh_a_hist_pre_min_em_df = ak.stock_zh_a_hist_pre_min_em(symbol="000001", start_time="09:00:00", end_time="15:40:00")
stock_zh_a_hist_pre_min_em_df
# Out:
#                       时间     开盘     收盘     最高     最低   成交量        成交额     最新价
# 0    2025-03-24 09:15:00  11.42  11.42  11.42  11.42     0        0.0  11.420
# 1    2025-03-24 09:16:00  11.38  11.42  11.42  11.38     0        0.0  11.420
# 2    2025-03-24 09:17:00  11.42  11.42  11.42  11.42     0        0.0  11.420
# 3    2025-03-24 09:18:00  11.42  11.42  11.42  11.42     0        0.0  11.420
# 4    2025-03-24 09:19:00  11.42  11.42  11.42  11.42     0        0.0  11.420
# ..                   ...    ...    ...    ...    ...   ...        ...     ...
# 210  2025-03-24 14:15:00  11.34  11.35  11.35  11.34  2537  2877436.0  11.385
# 211  2025-03-24 14:16:00  11.34  11.34  11.35  11.34  4524  5131095.0  11.385
# 212  2025-03-24 14:17:00  11.34  11.35  11.35  11.34  2902  3291766.0  11.385
# 213  2025-03-24 14:18:00  11.35  11.35  11.35  11.34  3790  4298574.0  11.385
# 214  2025-03-24 14:19:00  11.35  11.34  11.35  11.34   712   807449.0  11.385
#
# [215 rows x 8 columns]

# %% [markdown]
# ## 风险警示板

# %%
import akshare as ak

stock_zh_a_st_em_df = ak.stock_zh_a_st_em()
stock_zh_a_st_em_df
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#       序号      代码     名称    最新价    涨跌幅   涨跌额       成交量           成交额     振幅  \
# 0      1  600289  *ST信通   9.64   5.01  0.46  211152.0  2.034318e+08   1.63
# 1      2  600360   ST华微   6.29   5.01  0.30  273704.0  1.704479e+08   5.84
# 2      3  002310  *ST东园   2.12   4.95  0.10  796286.0  1.647274e+08   6.93
# 3      4  000584  *ST工智   2.76   4.94  0.13  228407.0  6.257969e+07   5.32
# 4      5  603828  ST柯利达   4.91   4.91  0.23   36750.0  1.804400e+07   0.00
# ..   ...     ...    ...    ...    ...   ...       ...           ...    ...
# 128  129  300108  *ST吉药   0.96  -7.69 -0.08  624450.0  6.061157e+07   7.69
# 129  130  300300   ST峡创   2.82  -8.14 -0.25  182975.0  5.344245e+07   7.17
# 130  131  300052  ST中青宝  10.53  -9.30 -1.08  318969.0  3.484700e+08  10.08
# 131  132  300208  *ST中程   2.04 -10.92 -0.25  215122.0  4.571493e+07  11.79
# 132  133  300630  *ST普利    NaN    NaN   NaN       NaN           NaN    NaN
#
#         最高     最低     今开     昨收    量比    换手率  市盈率-动态    市净率
# 0     9.64   9.49   9.64   9.18  2.45   3.73  158.66   8.42
# 1     6.29   5.94   6.01   5.99  0.80   2.85   44.54   1.80
# 2     2.12   1.98   2.01   2.02  1.39   1.90   -4.18   3.61
# 3     2.76   2.62   2.63   2.63  1.80   3.01   83.62   3.74
# 4     4.91   4.91   4.91   4.68  0.38   0.62  129.57   3.89
# ..     ...    ...    ...    ...   ...    ...     ...    ...
# 128   1.01   0.93   0.98   1.04  1.21   9.52   -2.07  -1.25
# 129   3.04   2.82   3.04   3.07  1.37   2.74  -27.10  13.75
# 130  11.63  10.46  11.58  11.61  1.03  12.18  -56.87   6.21
# 131   2.29   2.02   2.29   2.29  1.52   3.13   -8.69  -3.19
# 132    NaN    NaN    NaN   2.49   NaN   0.00  -10.67   0.46
#
# [133 rows x 17 columns]

# %% [markdown]
# ## 新股

# %%
stock_zh_a_new_em_df = ak.stock_zh_a_new_em()
stock_zh_a_new_em_df
# Out:
# 0it [00:00, ?it/s]
#     序号      代码    名称     最新价     涨跌幅     涨跌额     成交量           成交额     振幅  \
# 0    1  301629   N矽电  167.26  219.93  114.98   68863  1.237721e+09  47.76
# 1    2  603072  天和磁材   44.86   10.00    4.08  142198  6.187341e+08   9.91
# 2    3  301601  惠通科技   36.70    6.66    2.29  116547  4.129706e+08  13.11
# 3    4  301613  新铝时代   68.40    4.59    3.00   56587  4.046409e+08  15.20
# 4    5  301392  汇成真空   86.26    3.33    2.78   17211  1.500827e+08   6.85
# ..  ..     ...   ...     ...     ...     ...     ...           ...    ...
# 70  71  301592  六九一二  137.61   -7.24  -10.74   14220  2.027836e+08   7.37
# 71  72  688758  赛分科技   16.37   -7.77   -1.38   50976  8.623496e+07   8.56
# 72  73  301586   佳力奇   51.45   -8.06   -4.51   17377  9.256544e+07   8.35
# 73  74  603350   安乃达   35.48   -8.18   -3.16   37289  1.373758e+08   8.23
# 74  75  603124   C江南   51.41  -10.93   -6.31  112754  6.041083e+08   9.62
#
#         最高      最低      今开      昨收    量比    换手率  市盈率-动态    市净率
# 0   189.99  165.02  180.00   52.28   NaN  66.01   75.21   5.91
# 1    44.86   40.82   40.82   40.78  1.03  21.96   83.46   5.96
# 2    37.88   33.37   34.37   34.41  2.50  38.89   43.62   4.11
# 3    76.94   67.00   72.10   65.40  3.01  24.89   31.76   4.49
# 4    89.10   83.38   84.38   83.48  1.40   7.65  100.32  11.75
# ..     ...     ...     ...     ...   ...    ...     ...    ...
# 70  148.13  137.20  146.08  148.35  1.64   8.13  615.08  11.10
# 71   17.79   16.27   17.75   17.75  1.28  12.90   80.06   5.44
# 72   55.99   51.32   55.51   55.96  1.48   8.38   40.74   3.47
# 73   38.60   35.42   38.28   38.64  1.16  12.86   36.46   3.25
# 74   56.78   51.23   54.98   57.72  0.61  39.37   42.50   4.44
#
# [75 rows x 17 columns]

# %% [markdown]
# ## 千股千评

# %%
import akshare as ak

stock_comment_em_df = ak.stock_comment_em()
stock_comment_em_df
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
#         序号      代码       名称    最新价   涨跌幅    换手率     市盈率       主力成本     机构参与度  \
# 0        1  000001     平安银行  11.35 -0.61   0.51    4.95  11.451355  0.518491
# 1        2  000002    万  科Ａ   7.16 -2.72   0.91   -3.57   7.351065  0.475515
# 2        3  000004     国华网安  10.49 -9.96  10.86  -29.07  11.713059  0.126538
# 3        4  000006     深振业Ａ   6.45 -4.59   2.04  -12.47   6.615151  0.343428
# 4        5  000007      全新好   5.96 -4.79   1.55  487.59   6.244281  0.181530
# ...    ...     ...      ...    ...   ...    ...     ...        ...       ...
# 5107  5108  688799     华纳药厂  39.65 -1.49   1.12   21.58  40.327596  0.317270
# 5108  5109  688800      瑞可达  50.41 -2.42   1.72   46.18  52.206972  0.356507
# 5109  5110  688819     天能股份  28.79 -2.27   0.26   17.88  29.779290  0.222195
# 5110  5111  688981     中芯国际  89.85 -1.48   1.16  193.88  91.626926  0.487118
# 5111  5112  689009  九号公司-WD  62.72  1.65   1.55   41.36  61.831032  0.311061
#
#            综合得分    上升  目前排名  关注指数         交易日
# 0     60.432371   165  1972  83.6  2025-03-21
# 1     53.670348   -46  3998  76.4  2025-03-21
# 2     47.973750  -197  4905  68.8  2025-03-21
# 3     56.864219 -1834  3106  67.2  2025-03-21
# 4     59.434082 -1751  2322  60.4  2025-03-21
# ...         ...   ...   ...   ...         ...
# 5107  58.631857  -139  2586  57.6  2025-03-21
# 5108  58.346657  -329  2664  62.0  2025-03-21
# 5109  63.301316  -615  1153  69.2  2025-03-21
# 5110  55.135064   372  3599  80.0  2025-03-21
# 5111  65.589865  -303   697  74.4  2025-03-21
#
# [5112 rows x 14 columns]

# %% [markdown]
# ## 综合评价
# ### 历史评分

# %%
import akshare as ak

stock_comment_detail_zhpj_lspf_em_df = ak.stock_comment_detail_zhpj_lspf_em(symbol="600000")
stock_comment_detail_zhpj_lspf_em_df
# Out:
#            交易日         评分
# 0   2025-02-10  64.090264
# 1   2025-02-11  62.768164
# 2   2025-02-12  67.627188
# 3   2025-02-13  63.852792
# 4   2025-02-14  62.744769
# 5   2025-02-17  63.533842
# 6   2025-02-18  69.343782
# 7   2025-02-19  68.242250
# 8   2025-02-20  67.718586
# 9   2025-02-21  64.085335
# 10  2025-02-24  67.246829
# 11  2025-02-25  66.603342
# 12  2025-02-26  67.586055
# 13  2025-02-27  68.314121
# 14  2025-02-28  63.102330
# 15  2025-03-03  67.193228
# 16  2025-03-04  67.458102
# 17  2025-03-05  68.599364
# 18  2025-03-06  64.956747
# 19  2025-03-07  62.490772
# 20  2025-03-10  65.952973
# 21  2025-03-11  66.489865
# 22  2025-03-12  67.147350
# 23  2025-03-13  67.213116
# 24  2025-03-14  65.950877
# 25  2025-03-17  66.899376
# 26  2025-03-18  66.897658
# 27  2025-03-19  66.945040
# 28  2025-03-20  67.558656
# 29  2025-03-21  66.934438

# %% [markdown]
# ## 市场热度
# ### 用户关注指数

# %%
import akshare as ak

stock_comment_detail_scrd_focus_em_df = ak.stock_comment_detail_scrd_focus_em(symbol="600000")
stock_comment_detail_scrd_focus_em_df
# Out:
#            交易日  用户关注指数
# 0   2025-02-10    90.4
# 1   2025-02-11    88.4
# 2   2025-02-12    88.8
# 3   2025-02-13    88.8
# 4   2025-02-14    89.6
# 5   2025-02-17    90.0
# 6   2025-02-18    88.8
# 7   2025-02-19    90.8
# 8   2025-02-20    89.6
# 9   2025-02-21    88.8
# 10  2025-02-24    87.6
# 11  2025-02-25    88.0
# 12  2025-02-26    87.2
# 13  2025-02-27    87.6
# 14  2025-02-28    88.0
# 15  2025-03-03    88.8
# 16  2025-03-04    88.4
# 17  2025-03-05    87.6
# 18  2025-03-06    87.6
# 19  2025-03-07    87.2
# 20  2025-03-10    87.6
# 21  2025-03-11    87.2
# 22  2025-03-12    87.2
# 23  2025-03-13    86.8
# 24  2025-03-14    88.0
# 25  2025-03-17    88.4
# 26  2025-03-18    88.0
# 27  2025-03-19    88.0
# 28  2025-03-20    88.0
# 29  2025-03-21    88.0

# %% [markdown]
# ### 市场参与意愿

# %%
import akshare as ak

stock_comment_detail_scrd_desire_em_df = ak.stock_comment_detail_scrd_desire_em(symbol="600000")
stock_comment_detail_scrd_desire_em_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 import akshare as ak
# ----> 3 stock_comment_detail_scrd_desire_em_df = ak.stock_comment_detail_scrd_desire_em(symbol="600000")
#       4 stock_comment_detail_scrd_desire_em_df
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/stock_feature/stock_comment_em.py:249, in stock_comment_detail_scrd_desire_em(symbol)
#     245         time.sleep(1)
#     246         continue
#     248 date_str = (
# --> 249     data_json["ApiResults"]["scrd"]["desire"][0][0]["UpdateTime"]
#     250     .split(" ")[0]
#     251     .replace("/", "-")
#     252 )
#     254 temp_df = pd.DataFrame(
#     255     [
#     256         data_json["ApiResults"]["scrd"]["desire"][1]["XData"],
#    (...)    260     ]
#     261 ).T
#     262 temp_df.columns = ["日期时间", "大户", "全部", "散户"]
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ## 沪深港通资金流向

# %%
import akshare as ak

stock_hsgt_fund_flow_summary_em_df = ak.stock_hsgt_fund_flow_summary_em()
stock_hsgt_fund_flow_summary_em_df
# Out:
#           交易日   类型      板块 资金方向  交易状态     成交净买额  资金净流入  当日资金余额  上涨数  持平数  \
# 0  2025-03-24  沪港通     沪股通   北向     1  0.000000    0.0     0.0  287   22
# 1  2025-03-24  沪港通  港股通(沪)   南向     1  5.943012  420.0     0.0  128   33
# 2  2025-03-24  深港通     深股通   北向     1  0.000000    0.0     0.0  186   13
# 3  2025-03-24  深港通  港股通(深)   南向     1 -8.622522  420.0     0.0  128   33
#
#     下跌数  相关指数  指数涨跌幅
# 0   989  上证指数  -0.49
# 1   383  恒生指数  -0.31
# 2  1177  深证成指  -0.84
# 3   383  恒生指数  -0.31

# %% [markdown]
# ### 沪深港通分时数据

# %%
import akshare as ak

stock_hsgt_fund_min_em_df = ak.stock_hsgt_fund_min_em(symbol="北向资金")
stock_hsgt_fund_min_em_df
# Out:
#              日期     时间  沪股通  深股通  北向资金
# 0    2025-03-24   9:30  0.0  0.0   0.0
# 1    2025-03-24   9:31  0.0  0.0   0.0
# 2    2025-03-24   9:32  0.0  0.0   0.0
# 3    2025-03-24   9:33  0.0  0.0   0.0
# 4    2025-03-24   9:34  0.0  0.0   0.0
# ..          ...    ...  ...  ...   ...
# 236  2025-03-24  14:56  NaN  NaN   NaN
# 237  2025-03-24  14:57  NaN  NaN   NaN
# 238  2025-03-24  14:58  NaN  NaN   NaN
# 239  2025-03-24  14:59  NaN  NaN   NaN
# 240  2025-03-24  15:00  NaN  NaN   NaN
#
# [241 rows x 5 columns]

# %% [markdown]
# ### 板块排行

# %%
import akshare as ak

stock_hsgt_board_rank_em_df = ak.stock_hsgt_board_rank_em(symbol="北向资金增持行业板块排行", indicator="今日")
stock_hsgt_board_rank_em_df
# Out:
#     序号     名称  最新涨跌幅  北向资金今日持股-股票只数   北向资金今日持股-市值  北向资金今日持股-占板块比  \
# 0    1     银行   0.54             42  1.878734e+11       0.015709
# 1    2   通信服务  -4.41             18  1.089980e+10       0.003532
# 2    3   化学制药  -2.44             82  4.168693e+10       0.030978
# 3    4  光学光电子  -3.60             48  1.991344e+10       0.030229
# 4    5   消费电子  -2.68             50  5.397171e+10       0.038549
# ..  ..    ...    ...            ...           ...            ...
# 81  82   软件开发  -4.52             96  2.263597e+10       0.020477
# 82  83   有色金属  -0.84             51  2.315611e+10       0.027441
# 83  84     证券  -1.15             50  4.849522e+10       0.018636
# 84  85     电池  -3.49             43  8.986289e+10       0.067797
# 85  86   电力行业  -0.32             64  9.539639e+10       0.030862
#
#     北向资金今日持股-占北向资金比  北向资金今日增持估计-股票只数  北向资金今日增持估计-市值  北向资金今日增持估计-市值增幅  \
# 0          0.106654               32   1.190196e+09         0.645124
# 1          0.006188               13   4.695540e+08         4.602840
# 2          0.023665               47   3.284515e+08         0.802254
# 3          0.011305               35   2.496366e+08         1.272547
# 4          0.030639               34   1.770574e+08         0.332681
# ..              ...              ...            ...              ...
# 81         0.012850               26  -3.438477e+08        -1.484686
# 82         0.013146                4  -4.384133e+08        -1.864591
# 83         0.027530                8  -4.518683e+08        -0.916358
# 84         0.051014                3  -4.846157e+08        -0.535783
# 85         0.054156                3  -6.186249e+08        -0.639559
#
#     北向资金今日增持估计-占板块比  北向资金今日增持估计-占北向资金比 今日增持最大股-市值 今日增持最大股-占总市值比 今日减持最大股-市值  \
# 0          0.000100           0.000676       农业银行          齐鲁银行       宁波银行
# 1          0.000152           0.000267       中国联通          中国联通       中国移动
# 2          0.000244           0.000186       华东医药          普利制药       江苏吴中
# 3          0.000379           0.000142        欧菲光           欧菲光      TCL科技
# 4          0.000126           0.000101       立讯精密          得润电子       传音控股
# ..              ...                ...        ...           ...        ...
# 81        -0.000311          -0.000195        指南针          同有科技       柏楚电子
# 82        -0.000520          -0.000249       银邦股份          银邦股份       中国铝业
# 83        -0.000174          -0.000257       国盛金控          国盛金控       华泰证券
# 84        -0.000366          -0.000275        欣旺达           欣旺达       宁德时代
# 85        -0.000200          -0.000351       长江电力          中闽能源       中国核电
#
#    今日减持最大股-占总市值比        报告时间
# 0           宁波银行  2024-08-16
# 1           梦网科技  2024-08-16
# 2           江苏吴中  2024-08-16
# 3           华灿光电  2024-08-16
# 4           泰嘉股份  2024-08-16
# ..           ...         ...
# 81           高新兴  2024-08-16
# 82          鹏欣资源  2024-08-16
# 83          锦龙股份  2024-08-16
# 84          鹏辉能源  2024-08-16
# 85          涪陵电力  2024-08-16
#
# [86 rows x 17 columns]

# %% [markdown]
# ## 个股新闻

# %%
import akshare as ak

stock_news_em_df = ak.stock_news_em(symbol="300059")
stock_news_em_df
# Out:
#        关键词                                               新闻标题  \
# 0   300059               开源证券给予东方财富买入评级：证券市占率提升 持续深化AI+金融战略布局
# 1   300059            东方财富：公司自主研发的“妙想”金融大模型持续迭代升级 目前已升级深度思考模式
# 2   300059                    东方财富：目前已完成对DeepSeek大模型的本地化部署和测试
# 3   300059                            东方财富：2024年净利润同比增长17.29%
# 4   300059                     东方财富：2024年净利润96.1亿元 同比增长17.29%
# ..     ...                                                ...
# 95  300059      A股高质量龙头公司或迎配置机遇，A500ETF基金512050近3月新增规模居可比基金前列
# 96  300059                                    14股特大单净流入资金超2亿元
# 97  300059  消费品需求改善趋势有望延续，沪深300ETF平安510390备受关注，中证500ETF平安5...
# 98  300059             A股传统核心资产或出清加速，A500ETF基金512050成交额已超10亿元
# 99  300059                         创业板公司融资余额三连增 其间累计增加66.69亿元
#
#                                                  新闻内容                 发布时间  \
# 0   每经AI快讯，开源证券03月15日发布研报称，给予东方财富（300059.SZ）买入评级。评...  2025-03-16 11:45:20
# 1   东方财富（300059.SZ）3月14日在投资者互动平台表示，公司坚持以用户需求为中心，不断...  2025-03-15 22:59:29
# 2   东方财富（300059.SZ）3月14日在投资者互动平台表示，2023年，公司自主研发的“妙...  2025-03-15 22:55:46
# 3   每经AI快讯，3月14日，东方财富300059.SZ)公告称，公司2024年实现营业总收入1...  2025-03-14 20:04:18
# 4   人民财讯3月14日电，东方财富3000593月14日晚间披露2024年年报，2024年公司实...  2025-03-14 20:10:42
# ..                                                ...                  ...
# 95               300059、中信证券(600030)，前十大权重股合计占比20.3%。  2025-03-12 11:00:48
# 96  东方财富 23.35 -1.10 -4.76 非银金融 000581 威孚高科 23.49 ...  2025-03-13 21:15:06
# 97  数据显示，截至2025年1月27日，沪深300指数(000300)前十大权重股分别为贵州茅台...  2025-03-12 13:27:27
# 98               300059、中信证券(600030)，前十大权重股合计占比20.3%。  2025-03-10 10:58:08
# 99  东方财富 245.34 1.61 300401 花园生物 6.89 -0.71 300083...  2025-03-13 09:30:32
#
#       文章来源                                               新闻链接
# 0   每日经济新闻  http://finance.eastmoney.com/a/202503163346870...
# 1   每日经济新闻  http://finance.eastmoney.com/a/202503153346788...
# 2   每日经济新闻  http://finance.eastmoney.com/a/202503153346787...
# 3   每日经济新闻  http://finance.eastmoney.com/a/202503143346284...
# 4     人民财讯  http://finance.eastmoney.com/a/202503143346294...
# ..     ...                                                ...
# 95    界面新闻  http://stock.eastmoney.com/a/20250312334344379...
# 96   证券时报网  http://finance.eastmoney.com/a/202503133345119...
# 97    界面新闻  http://stock.eastmoney.com/a/20250312334354257...
# 98    界面新闻  http://stock.eastmoney.com/a/20250310334106831...
# 99   证券时报网  http://finance.eastmoney.com/a/202503133344468...
#
# [100 rows x 6 columns]

# %% [markdown]
# ## 财经内容精选

# %%
import akshare as ak

stock_news_main_cx_df = ak.stock_news_main_cx()
stock_news_main_cx_df
# Out:
#                      tag                                            summary  \
# 0                 今日市场热点  有色金属概念股逆市拉升，电工合金等股涨停，消息面上，近期国际铜价持续走高；旅游股震荡走强，传...
# 1       数据推荐：消费者信心指数连升三月  国家统计局数据显示，2月全国消费者信心指数录得88.4，较1月升高0.9个百分点，连续第三个...
# 2        “新质产业”能缓解就业压力吗？  “最敢生的省份也开始抢人了”，社交媒体上颇受关注的这个标签，背后是广东省2025年春招。新技...
# 3      数据发现：3月中旬豆粕价格继续回落  国家统计局今日公布了3月中旬流通领域重要生产资料市场价格变动情况。农产品豆粕（粗蛋白含量≥4...
# 4      数据发现：土耳其3月消费者信心改善  土耳其消费者信心指数从2月份的82.1升至3月份的85.9。这是自2023年5月以来的最高水...
# ...                  ...                                                ...
# 14840     （接上条）广电的5G牌怎么打  相比三大运营商，中国广电是5G赛道新玩家，也得想点新玩法。中国广电持股51%、注册资本超千亿...
# 14841           5G建设最新数据  据财新报道，目前中国已开通5G基站超70万个，97%共享既有站址。分运营商来看，中国联通和中...
# 14842       银行股尾盘爆发有何道理？  今日（11月27日）A股银行板块午后拉升领涨，尾盘爆发。财新数据通11月22日的多图深度剖析...
# 14843  鸿海或将部分苹果产品生产线迁出中国  消息称，鸿海将把苹果公司的部分iPad和MacBook生产线从中国迁往越南，原因是该公司寻求...
# 14844          “小酒”股今日普跌  11月27日A股开盘后，多只“小酒”股出现大幅回撤，领跌食品饮料板块。这时候不妨重温我们昨天...
#
#           interval_time                 pub_time  \
# 0                 43分钟前  2025-03-24 05:45:37.270
# 1                  1小时前  2025-03-24 04:50:00.000
# 2                  2小时前  2025-03-24 04:00:00.000
# 3                  3小时前  2025-03-24 03:00:00.000
# 4                  4小时前  2025-03-24 01:30:00.000
# ...                 ...                      ...
# 14840  2020-11-27 17:18  2020-11-27 09:18:03.901
# 14841  2020-11-27 17:17  2020-11-27 09:17:30.084
# 14842  2020-11-27 17:05  2020-11-27 09:05:36.408
# 14843  2020-11-27 17:05  2020-11-27 09:05:05.090
# 14844  2020-11-27 16:59  2020-11-27 08:59:21.686
#
#                                                      url
# 0      https://database.caixin.com/2025-03-24/1023015...
# 1          https://a.caixin.com/1LDJ6atg?cxapp_link=true
# 2      https://database.caixin.com/2025-03-21/1023007...
# 3          https://a.caixin.com/JHm44UG3?cxapp_link=true
# 4          https://a.caixin.com/HaLa2GyX?cxapp_link=true
# ...                                                  ...
# 14840  https://cxdata.caixin.com/twotopic/20200925153...
# 14841  http://www.caixin.com/2020-11-26/101632865.htm...
# 14842  http://database.caixin.com/2020-11-22/10163123...
# 14843  http://database.caixin.com/2020-11-27/10163291...
# 14844  http://database.caixin.com/2020-11-26/10163250...
#
# [14845 rows x 5 columns]

# %% [markdown]
# ## 资金流向

# %% [markdown]
# ### 同花顺

# %% [markdown]
# #### 个股资金流

# %%
import akshare as ak

stock_fund_flow_individual_df = ak.stock_fund_flow_individual(symbol="即时")
stock_fund_flow_individual_df
# Out:
#   0%|          | 0/104 [00:00<?, ?it/s]
#         序号    股票代码  股票简称     最新价      涨跌幅     换手率    流入资金    流出资金         净额  \
# 0        1  300071  福石控股    5.08   20.09%  14.16%   3.56亿   2.80亿   7583.27万
# 1        2  300300  海峡创新   10.25   20.02%  42.56%  16.46亿  10.38亿      6.08亿
# 2        3  301231  荣信文化   39.60   20.00%  18.56%   1.58亿   2.20亿  -6254.55万
# 3        4  688095  福昕软件  107.40   20.00%  11.55%   5.99亿   4.56亿      1.43亿
# 4        5  688336  三生国健   72.96   20.00%   1.87%   4.28亿   3.71亿   5658.47万
# ...    ...     ...   ...     ...      ...     ...     ...     ...        ...
# 5148  5149  301377  鼎泰高科  123.00  -10.68%  29.29%  13.31亿  12.79亿   5161.10万
# 5149  5150  688252   天德钰   24.48  -10.95%   9.61%   1.77亿   2.55亿  -7773.94万
# 5150  5151  688205   德科立   94.36  -11.35%   9.69%   6.82亿   8.26亿     -1.44亿
# 5151  5152  688169  石头科技  163.40  -12.04%   4.59%   9.24亿  10.13亿  -8944.80万
# 5152  5153  688596  正帆科技   32.85  -14.30%  12.11%   5.46亿   6.27亿  -8083.30万
#
#          成交额
# 0      6.39亿
# 1     26.86亿
# 2      3.78亿
# 3     10.56亿
# 4      7.99亿
# ...      ...
# 5148  26.11亿
# 5149   4.32亿
# 5150  15.08亿
# 5151  19.37亿
# 5152  11.73亿
#
# [5153 rows x 10 columns]

# %% [markdown]
# #### 概念资金流

# %%
import akshare as ak

stock_fund_flow_concept_df = ak.stock_fund_flow_concept(symbol="即时")
stock_fund_flow_concept_df
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# /Users/zhengshuang/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/stock_feature/stock_fund_flow.py:204: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   big_df = pd.concat(objs=[big_df, temp_df], ignore_index=True)
#       序号       行业     行业指数  行业-涨跌幅    流入资金    流出资金      净额 公司家数   领涨股  \
# 0      1     环氧丙烷  1254.32    0.92   25.99   26.38   -0.39   16  怡达股份
# 1      2  同花顺出海50  1354.28    0.65  175.78  162.35   13.44   50  洛阳钼业
# 2      3     超级品牌  1547.35    0.31  120.25  107.14   13.11   42   张小泉
# 3      4    钛白粉概念  1404.79    0.27    8.25    7.33    0.92   14  安宁股份
# 4      5      磷化工  2017.33    0.09   59.90   51.60    8.30   49  湖北宜化
# ..   ...      ...      ...     ...     ...     ...     ...  ...   ...
# 321  322     房屋检测  1490.05   -3.70   14.74   24.71   -9.96   43  华测检测
# 322  323    PM2.5  1306.12   -3.71   12.33   20.50   -8.17   40  中创环保
# 323  324      区块链  1466.99   -3.73  303.53  444.59 -141.06  240  安通控股
# 324  325     数字货币  1995.78   -3.73  102.77  140.79  -38.01   83  东港股份
# 325  326     噪声防治  1324.39   -3.74    4.70    7.79   -3.09   18  玉马科技
#
#      领涨股-涨跌幅    当前价
# 0      16.31  17.83
# 1       4.58   7.99
# 2      19.98  19.04
# 3       6.04  32.83
# 4      10.00  14.74
# ..       ...    ...
# 321    -0.38  13.21
# 322     1.94  15.28
# 323     3.41   3.03
# 324     3.35  14.21
# 325     0.64  10.94
#
# [326 rows x 11 columns]

# %% [markdown]
# #### 行业资金流

# %%
import akshare as ak

stock_fund_flow_industry_df = ak.stock_fund_flow_industry(symbol="即时")
stock_fund_flow_industry_df
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#     序号     行业       行业指数  行业-涨跌幅    流入资金    流出资金     净额  公司家数   领涨股  领涨股-涨跌幅  \
# 0    1  旅游及酒店   3116.300    2.60   40.26   39.46   0.80    34   张家界    10.04
# 1    2     保险   2093.170    1.02   18.86   19.11  -0.25     6  新华保险     1.65
# 2    3     银行   1205.630    0.68   79.89   64.17  15.73    84  交通银行     3.19
# 3    4   工业金属   2900.800    0.37  127.02  110.00  17.01    59  电工合金    20.00
# 4    5   机场航运   2027.590    0.30    9.06   10.96  -1.90    13  吉祥航空     2.92
# ..  ..    ...        ...     ...     ...     ...    ...   ...   ...      ...
# 85  86   软件开发   2091.880   -3.89  129.34  170.26 -40.93   137  立方数科     5.68
# 86  87   轨交设备    916.238   -3.90    9.65   16.42  -6.78    29  中国通号     0.00
# 87  88     教育   4451.780   -3.96    9.32   14.81  -5.49    17  行动教育     0.29
# 88  89   军工电子   9999.980   -3.99   41.38   63.64 -22.26    62  天和防务     1.45
# 89  90   IT服务  11630.500   -4.19  142.71  209.39 -66.68   126  志晟信息     2.82
#
#       当前价
# 0    8.11
# 1   51.28
# 2    7.44
# 3   17.34
# 4   13.02
# ..    ...
# 85  12.84
# 86   5.61
# 87  42.09
# 88  15.42
# 89  32.80
#
# [90 rows x 11 columns]

# %% [markdown]
# #### 大单追踪

# %%
import akshare as ak

stock_fund_flow_big_deal_df = ak.stock_fund_flow_big_deal()
stock_fund_flow_big_deal_df
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#                      成交时间    股票代码  股票简称    成交价格     成交量     成交额 大单性质      涨跌幅  \
# 0     2025-03-24 14:34:02  300311   任子行    6.62  124400   82.23   卖盘   -4.33%
# 1     2025-03-24 14:34:02  300750  宁德时代  257.91    2800   72.21   卖盘    0.75%
# 2     2025-03-24 14:34:02  300738  奥飞数据   23.25   24000   55.82   买盘   -4.24%
# 3     2025-03-24 14:34:02  300217  东方电热    5.18  222100  114.35   卖盘   -4.43%
# 4     2025-03-24 14:34:02    2559  亚威股份   10.89  200000  217.80   买盘  -10.00%
# ...                   ...     ...   ...     ...     ...     ...  ...      ...
# 4995  2025-03-24 14:22:02    2400  省广集团    7.96  419700  329.04   买盘   -2.57%
# 4996  2025-03-24 14:22:02  300870   欧陆通  142.73   13700  191.22   买盘   -3.76%
# 4997  2025-03-24 14:22:02  300083   创世纪    9.07   70800   63.22   买盘   -6.59%
# 4998  2025-03-24 14:22:02     651  格力电器   45.09   64500  289.73   买盘    3.09%
# 4999  2025-03-24 14:22:02     651  格力电器   45.09   55200  247.90   买盘    3.09%
#
#        涨跌额
# 0    -0.29
# 1     1.92
# 2    -0.99
# 3    -0.23
# 4    -1.09
# ...    ...
# 4995 -0.20
# 4996 -5.36
# 4997 -0.60
# 4998  1.39
# 4999  1.39
#
# [5000 rows x 9 columns]

# %% [markdown]
# ### 东方财富

# %% [markdown]
# #### 个股资金流

# %%
import akshare as ak

stock_individual_fund_flow_df = ak.stock_individual_fund_flow(stock="600094", market="sh")
stock_individual_fund_flow_df
# Out:
#              日期   收盘价   涨跌幅    主力净流入-净额  主力净流入-净占比  超大单净流入-净额  超大单净流入-净占比  \
# 0    2024-09-19  3.30  3.13  -1386998.0      -2.30 -4724258.0       -7.82
# 1    2024-09-20  3.43  3.94  15092952.0      13.11  2452932.0        2.13
# 2    2024-09-23  3.33 -2.92 -10954379.0     -15.46 -6253897.0       -8.83
# 3    2024-09-24  3.50  5.11   9448784.0       9.02 -3497171.0       -3.34
# 4    2024-09-25  3.58  2.29  -6608357.0      -3.76  1070893.0        0.61
# ..          ...   ...   ...         ...        ...        ...         ...
# 115  2025-03-17  3.48 -0.29  -5157873.0      -7.03 -3684110.0       -5.02
# 116  2025-03-18  3.48  0.00    154011.0       0.25  3466232.0        5.74
# 117  2025-03-19  3.41 -2.01  -6554224.0      -8.93 -3382747.0       -4.61
# 118  2025-03-20  3.40 -0.29  -4618784.0      -8.42  -609950.0       -1.11
# 119  2025-03-21  3.35 -1.47   2041046.0       3.68  1967127.0        3.54
#
#        大单净流入-净额  大单净流入-净占比   中单净流入-净额  中单净流入-净占比    小单净流入-净额  小单净流入-净占比
# 0     3337260.0       5.53 -1831242.0      -3.03   3218240.0       5.33
# 1    12640020.0      10.98 -2566885.0      -2.23 -12526067.0     -10.88
# 2    -4700482.0      -6.63  5750242.0       8.12   5204137.0       7.35
# 3    12945955.0      12.35 -6361381.0      -6.07  -3087403.0      -2.95
# 4    -7679250.0      -4.37  7534788.0       4.29   -926432.0      -0.53
# ..          ...        ...        ...        ...         ...        ...
# 115  -1473763.0      -2.01  -505840.0      -0.69   5663713.0       7.72
# 116  -3312221.0      -5.48  -378645.0      -0.63    224634.0       0.37
# 117  -3171477.0      -4.32  4132192.0       5.63   2422032.0       3.30
# 118  -4008834.0      -7.31  -511440.0      -0.93   5130224.0       9.35
# 119     73919.0       0.13 -4167192.0      -7.51   2126146.0       3.83
#
# [120 rows x 13 columns]

# %% [markdown]
# #### 个股资金流排名

# %%
import akshare as ak

stock_individual_fund_flow_rank_df = ak.stock_individual_fund_flow_rank(indicator="今日")
stock_individual_fund_flow_rank_df
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[9], line 3
#       1 import akshare as ak
# ----> 3 stock_individual_fund_flow_rank_df = ak.stock_individual_fund_flow_rank(indicator="今日")
#       4 stock_individual_fund_flow_rank_df
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/stock/stock_fund_em.py:162, in stock_individual_fund_flow_rank(indicator)
#     149 url = "https://push2.eastmoney.com/api/qt/clist/get"
#     150 params = {
#     151     "fid": indicator_map[indicator][0],
#     152     "po": "1",
#    (...)    160     "fields": indicator_map[indicator][1],
#     161 }
# --> 162 r = requests.get(url, params=params)
#     163 data_json = r.json()
#     164 total_page = math.ceil(data_json["data"]["total"] / 100)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)    678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# #### 大盘资金流

# %%
stock_market_fund_flow_df = ak.stock_market_fund_flow()
stock_market_fund_flow_df
# Out:
#              日期   上证-收盘价  上证-涨跌幅    深证-收盘价  深证-涨跌幅      主力净流入-净额  主力净流入-净占比  \
# 0    2024-09-19  2736.02    0.69   8087.60    1.19  5.354226e+09       0.85
# 1    2024-09-20  2736.81    0.03   8075.14   -0.15 -1.189129e+10      -2.07
# 2    2024-09-23  2748.92    0.44   8083.38    0.10 -6.702560e+09      -1.22
# 3    2024-09-24  2863.13    4.15   8435.70    4.36  2.795806e+10       2.88
# 4    2024-09-25  2896.31    1.16   8537.73    1.21 -1.440067e+10      -1.24
# ..          ...      ...     ...       ...     ...           ...        ...
# 115  2025-03-17  3426.13    0.19  10957.82   -0.19 -3.532275e+10      -2.25
# 116  2025-03-18  3429.76    0.11  11014.75    0.52 -2.828635e+10      -1.86
# 117  2025-03-19  3426.43   -0.10  10979.05   -0.32 -5.739795e+10      -3.91
# 118  2025-03-20  3408.95   -0.51  10879.49   -0.91 -3.584253e+10      -2.49
# 119  2025-03-21  3364.83   -1.29  10687.55   -1.76 -9.622171e+10      -6.20
#
#         超大单净流入-净额  超大单净流入-净占比      大单净流入-净额  大单净流入-净占比      中单净流入-净额  \
# 0    3.472006e+09        0.55  1.882220e+09       0.30 -5.612552e+09
# 1   -4.991644e+09       -0.87 -6.899648e+09      -1.20  1.267753e+08
# 2   -9.265308e+08       -0.17 -5.776029e+09      -1.05 -1.261220e+09
# 3    2.252485e+10        2.32  5.433213e+09       0.56 -2.228290e+10
# 4   -4.010342e+09       -0.35 -1.039033e+10      -0.90 -5.641708e+08
# ..            ...         ...           ...        ...           ...
# 115 -1.817892e+10       -1.16 -1.714383e+10      -1.09  9.071153e+09
# 116 -9.027236e+09       -0.59 -1.925911e+10      -1.27 -2.415890e+09
# 117 -2.868831e+10       -1.96 -2.870965e+10      -1.96  7.528944e+09
# 118 -1.456764e+10       -1.01 -2.127488e+10      -1.48  1.828946e+08
# 119 -5.077143e+10       -3.27 -4.545028e+10      -2.93  1.337560e+10
#
#      中单净流入-净占比      小单净流入-净额  小单净流入-净占比
# 0        -0.90  2.583265e+08       0.04
# 1         0.02  1.176451e+10       2.05
# 2        -0.23  7.963779e+09       1.45
# 3        -2.29 -5.675168e+09      -0.58
# 4        -0.05  1.496484e+10       1.29
# ..         ...           ...        ...
# 115       0.58  2.625160e+10       1.67
# 116      -0.16  3.070224e+10       2.02
# 117       0.51  4.986901e+10       3.40
# 118       0.01  3.565964e+10       2.47
# 119       0.86  8.284611e+10       5.34
#
# [120 rows x 15 columns]

# %% [markdown]
# #### 板块资金流排名

# %%
import akshare as ak

stock_sector_fund_flow_rank_df = ak.stock_sector_fund_flow_rank(indicator="今日", sector_type="行业资金流")
stock_sector_fund_flow_rank_df
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#     序号     名称  今日涨跌幅    今日主力净流入-净额  今日主力净流入-净占比   今日超大单净流入-净额  今日超大单净流入-净占比  \
# 0    1   有色金属  -0.14  1.051296e+09         3.01  7.458798e+08          2.14
# 1    2   化肥行业   1.24  7.664125e+08         8.49  8.329895e+08          9.23
# 2    3   旅游酒店   2.52  4.954419e+08         3.63  4.139178e+08          3.03
# 3    4     银行   0.74  3.141305e+08         1.51  2.805018e+08          1.35
# 4    5   电力行业   0.14  2.023747e+08         0.91  7.483936e+06          0.03
# ..  ..    ...    ...           ...          ...           ...           ...
# 81  82  汽车零部件  -2.92 -4.112262e+09        -6.90 -1.630146e+09         -2.73
# 82  83   专用设备  -2.92 -4.822416e+09        -7.61 -2.337014e+09         -3.69
# 83  84   通用设备  -3.31 -5.385415e+09        -8.92 -2.672437e+09         -4.43
# 84  85   软件开发  -3.47 -5.942664e+09        -9.27 -2.534203e+09         -3.95
# 85  86  互联网服务  -3.94 -9.272970e+09       -12.00 -5.217600e+09         -6.75
#
#       今日大单净流入-净额  今日大单净流入-净占比    今日中单净流入-净额  今日中单净流入-净占比    今日小单净流入-净额  \
# 0   3.054164e+08         0.88 -8.133258e+08        -2.33 -2.228641e+08
# 1  -6.657698e+07        -0.74 -4.131819e+08        -4.58 -3.532722e+08
# 2   8.152413e+07         0.60  8.801818e+07         0.65 -5.831660e+08
# 3   3.362867e+07         0.16 -1.029274e+09        -4.96  7.152246e+08
# 4   1.948908e+08         0.88 -3.585815e+08        -1.61  1.560594e+08
# ..           ...          ...           ...          ...           ...
# 81 -2.482117e+09        -4.16 -7.147162e+07        -0.12  4.096056e+09
# 82 -2.485402e+09        -3.92  6.388485e+08         1.01  4.054480e+09
# 83 -2.712978e+09        -4.49  3.212040e+08         0.53  4.944563e+09
# 84 -3.408461e+09        -5.31  4.251256e+08         0.66  5.438337e+09
# 85 -4.055370e+09        -5.25  6.569930e+08         0.85  8.603529e+09
#
#     今日小单净流入-净占比 今日主力净流入最大股
# 0         -0.64       铜陵有色
# 1         -3.91       湖北宜化
# 2         -4.27       峨眉山Ａ
# 3          3.45       交通银行
# 4          0.70       长江电力
# ..          ...        ...
# 81         6.87       福达股份
# 82         6.40       合锻智能
# 83         8.19        四方达
# 84         8.48       立方数科
# 85        11.13       ST联合
#
# [86 rows x 14 columns]

# %% [markdown]
# #### 主力净流入排名

# %%
import akshare as ak

stock_main_fund_flow_df = ak.stock_main_fund_flow(symbol="全部股票")
stock_main_fund_flow_df
# Out:
#   0%|          | 0/52 [00:00<?, ?it/s]
#         序号      代码    名称     最新价  今日排行榜-主力净占比  今日排行榜-今日排名  今日排行榜-今日涨跌  \
# 0        1  301629   N矽电  164.86        35.47         9.0      215.34
# 1        2  300697  电工合金   17.34        14.22        88.0       20.00
# 2        3  688178   万德斯   20.48        23.22        24.0       19.98
# 3        4  301055   张小泉   19.04        29.39        15.0       19.97
# 4        5  301025  读客文化   10.94        20.96        34.0       19.96
# ...    ...     ...   ...     ...          ...         ...         ...
# 5222  5223  300175  朗源股份     NaN          NaN         NaN         NaN
# 5223  5224  300147  香雪制药     NaN          NaN         NaN         NaN
# 5224  5225  002529  海源复材     NaN          NaN         NaN         NaN
# 5225  5226  001335  信凯科技     NaN          NaN         NaN         NaN
# 5226  5227  000722  湖南发展     NaN          NaN         NaN         NaN
#
#       5日排行榜-主力净占比  5日排行榜-5日排名  5日排行榜-5日涨跌  10日排行榜-主力净占比  10日排行榜-10日排名  \
# 0           35.47           1      215.34         35.47             1
# 1            4.12         277       19.18          1.35           659
# 2           23.22           4       19.98         18.16             3
# 3           13.71          14       25.68          7.94            28
# 4           13.54          16       13.84          9.10            19
# ...           ...         ...         ...           ...           ...
# 5222       -11.02        5080       -6.61         -7.08          5021
# 5223        -1.48        1757        1.73         -1.21          2002
# 5224         3.46         355       15.60          3.16           275
# 5225          NaN        1194         NaN           NaN          1247
# 5226        10.79          31        4.75          6.28            59
#
#       10日排行榜-10日涨跌  所属板块
# 0           215.34   半导体
# 1            19.26  有色金属
# 2            32.81  环保行业
# 3            30.05  通用设备
# 4            15.52  文化传媒
# ...            ...   ...
# 5222         -6.61  农牧饲渔
# 5223          0.40    中药
# 5224         17.19  专用设备
# 5225           NaN  化学制品
# 5226         13.68  电力行业
#
# [5227 rows x 14 columns]

# %% [markdown]
# #### 行业个股资金流

# %%
import akshare as ak

stock_sector_fund_flow_summary_df = ak.stock_sector_fund_flow_summary(symbol="电源设备", indicator="今日")
stock_sector_fund_flow_summary_df
# Out:
# 0it [00:00, ?it/s]
#     序号      代码     名称     最新价  今天涨跌幅   今日主力净流入-净额  今日主力净流入-净占比  今日超大单净流入-净额  \
# 0    1  002630   华西能源    5.09   9.94  141958882.0        21.91  137072161.0
# 1    2  300153   科泰电源   41.71   1.36   13173205.0         0.95   24231029.0
# 2    3  600202    哈空调    5.30   2.91   12557524.0         3.99   13166188.0
# 3    4  002534   西子洁能   13.25  -0.75    7384446.0         5.82    1331703.0
# 4    5  688719   爱科赛博   30.57  -2.89    4107599.0         8.22    7215147.0
# 5    6  000576   甘化科工    7.52  -3.84    2734509.0         2.86    -483354.0
# 6    7  301386   未来电器   20.80  -3.53   -4017856.0       -11.60          0.0
# 7    8  300820   英杰电气   49.89  -3.05   -4843049.0        -2.74    4060025.0
# 8    9  600475   华光环能    9.19   0.22   -4900926.0       -12.03    -482826.0
# 9   10  301516    中远通   16.77  -4.50   -5936803.0        -7.96          0.0
# 10  11  300105   龙源技术    7.15  -2.99   -6515455.0        -4.82    -899153.0
# 11  12  600875   东方电气   15.22   0.46   -7980575.0        -2.94   -6799367.0
# 12  13  688551    科威尔   28.18  -5.12   -9796276.0       -28.53   -6705506.0
# 13  14  300376  ST易事特    3.47  -3.61  -14893603.0       -20.49    -791158.0
# 14  15  301327   华宝新能   80.55  -1.42  -19519849.0       -16.86   -3068292.0
# 15  16  300713    英可瑞   17.04  -7.39  -20025950.0        -8.87   -2462637.0
# 16  17  300491   通合科技   19.28  -5.35  -20486906.0       -10.22  -11176553.0
# 17  18  002227  奥 特 迅   12.47  -9.96  -23859420.0        -7.31   -6056789.0
# 18  19  600405    动力源    5.32  -3.62  -25468011.0       -18.93   -9555046.0
# 19  20  300593    新雷能   14.72  -3.98  -25566448.0        -9.97  -12057002.0
# 20  21  002366   融发核电    5.06  -2.50  -29675491.0        -5.10   -7970114.0
# 21  22  300693   盛弘股份   37.23  -0.69  -30110774.0        -9.73  -21670341.0
# 22  23  300870    欧陆通  141.94  -4.29  -44892559.0        -8.73   11058792.0
# 23  24  002518    科士达   26.62  -2.02  -46017486.0       -11.50  -22043627.0
# 24  25  002364   中恒电气   15.17  -2.76  -51069946.0        -8.90  -29455973.0
# 25  26  688411   海博思创   78.00  -5.13  -62753935.0       -25.01  -23645160.0
# 26  27  002255   海陆重工    7.08  -4.71  -76523340.0        -9.39  -35880860.0
# 27  28  601727   上海电气    7.74  -2.52 -146011875.0       -13.77  -30936157.0
# 28  29  002851   麦格米特   58.74  -1.99 -147580474.0       -13.28  -96694458.0
# 29  30  002335   科华数据   45.97  -4.61 -180863472.0       -10.58  -66543440.0
#
#     今日超大单净流入-净占比   今日大单净流入-净额  今日大单净流入-净占比  今日中单净流入-净额  今日中单净流入-净占比  \
# 0          21.16    4886721.0         0.75 -66679447.0       -10.29
# 1           1.74  -11057824.0        -0.79 -38326160.0        -2.75
# 2           4.18    -608664.0        -0.19  13074476.0         4.15
# 3           1.05    6052743.0         4.77  -1878603.0        -1.48
# 4          14.44   -3107548.0        -6.22  -2574447.0        -5.15
# 5          -0.51    3217863.0         3.37   8901576.0         9.32
# 6           0.00   -4017856.0       -11.60  -1001954.0        -2.89
# 7           2.30   -8903074.0        -5.04  -3811782.0        -2.16
# 8          -1.19   -4418100.0       -10.85  -5471121.0       -13.43
# 9           0.00   -5936803.0        -7.96    230270.0         0.31
# 10         -0.67   -5616302.0        -4.15  -4615293.0        -3.41
# 11         -2.51   -1181208.0        -0.44  -5596426.0        -2.06
# 12        -19.53   -3090770.0        -9.00   4170023.0        12.14
# 13         -1.09  -14102445.0       -19.40   1913741.0         2.63
# 14         -2.65  -16451557.0       -14.21  -5622567.0        -4.86
# 15         -1.09  -17563313.0        -7.78  -9434493.0        -4.18
# 16         -5.58   -9310353.0        -4.65  -2717195.0        -1.36
# 17         -1.85  -17802631.0        -5.45 -16407846.0        -5.02
# 18         -7.10  -15912965.0       -11.82    576353.0         0.43
# 19         -4.70  -13509446.0        -5.27  -8854068.0        -3.45
# 20         -1.37  -21705377.0        -3.73  -4387493.0        -0.75
# 21         -7.01   -8440433.0        -2.73  -9048700.0        -2.93
# 22          2.15  -55951351.0       -10.88   -406349.0        -0.08
# 23         -5.51  -23973859.0        -5.99  -4411740.0        -1.10
# 24         -5.13  -21613973.0        -3.77 -15208508.0        -2.65
# 25         -9.42  -39108775.0       -15.59  36693219.0        14.62
# 26         -4.40  -40642480.0        -4.99  -7549898.0        -0.93
# 27         -2.92 -115075718.0       -10.85 -31768896.0        -3.00
# 28         -8.70  -50886016.0        -4.58  15096672.0         1.36
# 29         -3.89 -114320032.0        -6.69 -17216704.0        -1.01
#
#      今日小单净流入-净额  今日小单净流入-净占比
# 0   -75279436.0       -11.62
# 1    25152960.0         1.81
# 2   -25637300.0        -8.14
# 3    -5505842.0        -4.34
# 4    -1533152.0        -3.07
# 5   -11636085.0       -12.18
# 6     5019810.0        14.49
# 7     8654831.0         4.90
# 8    10372047.0        25.46
# 9     5706534.0         7.65
# 10   11130748.0         8.23
# 11   13575480.0         5.00
# 12    5626254.0        16.38
# 13   12979862.0        17.86
# 14   25142415.0        21.71
# 15   29460444.0        13.05
# 16   23204101.0        11.58
# 17   40267266.0        12.33
# 18   24891657.0        18.50
# 19   34420517.0        13.42
# 20   34062985.0         5.85
# 21   39159475.0        12.66
# 22   45298908.0         8.81
# 23   50429226.0        12.60
# 24   66278454.0        11.55
# 25   26060716.0        10.39
# 26   84073245.0        10.32
# 27  177777664.0        16.76
# 28  132483810.0        11.92
# 29  198080176.0        11.59

# %% [markdown]
# ## 筹码分布

# %%
import akshare as ak

stock_cyq_em_df = ak.stock_cyq_em(symbol="000001", adjust="")
stock_cyq_em_df
# Out:
#             日期      获利比例   平均成本  90成本-低  90成本-高     90集中度  70成本-低  70成本-高  \
# 0   2024-11-08  0.684546  11.33    9.94   12.30  0.106030   10.10   11.97
# 1   2024-11-11  0.638230  11.35    9.94   12.28  0.104998   10.10   11.97
# 2   2024-11-12  0.601603  11.35    9.94   12.28  0.104998   10.10   11.97
# 3   2024-11-13  0.648730  11.38    9.94   12.25  0.103964   10.10   11.94
# 4   2024-11-14  0.591761  11.38    9.94   12.25  0.103964   10.12   11.94
# ..         ...       ...    ...     ...     ...       ...     ...     ...
# 85  2025-03-18  0.443982  11.53   10.05   12.02  0.089464   10.38   11.84
# 86  2025-03-19  0.490465  11.53   10.05   12.02  0.089464   10.38   11.84
# 87  2025-03-20  0.440690  11.53   10.05   12.02  0.089464   10.40   11.84
# 88  2025-03-21  0.344380  11.53   10.05   12.02  0.089464   10.40   11.84
# 89  2025-03-24  0.285811  11.53   10.07   12.02  0.088200   10.40   11.84
#
#        70集中度
# 0   0.084817
# 1   0.084817
# 2   0.084817
# 3   0.083752
# 4   0.082493
# ..       ...
# 85  0.065768
# 86  0.065768
# 87  0.064540
# 88  0.064540
# 89  0.064540
#
# [90 rows x 9 columns]

# %% [markdown]
# ## 股票热度

# %% [markdown]
# ### 股票热度-雪球

# %% [markdown]
# #### 关注排行榜

# %%
stock_hot_follow_xq_df = ak.stock_hot_follow_xq(symbol="最热门")
stock_hot_follow_xq_df
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
#           股票代码   股票简称         关注      最新价
# 0     SH600519   贵州茅台  3159704.0  1584.89
# 1     SH601318   中国平安  2657448.0    52.12
# 2     SH600036   招商银行  2396116.0    45.06
# 3     SZ000651   格力电器  2095777.0    45.00
# 4     SZ002594    比亚迪  1868033.0   374.33
# ...        ...    ...        ...      ...
# 5482  BJ833874   泰祥股份      495.0    19.63
# 5483  BJ870866   绿亨科技      485.0     8.68
# 5484  BJ873339   恒太照明      400.0    11.05
# 5485  SZ300114   中航电测      382.0    72.18
# 5486  SZ301629  N矽电股份        NaN   161.35
#
# [5487 rows x 4 columns]

# %% [markdown]
# #### 交易排行榜

# %%
stock_hot_deal_xq_df = ak.stock_hot_deal_xq(symbol="最热门")
stock_hot_deal_xq_df
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
#           股票代码   股票简称     关注      最新价
# 0     SH600519   贵州茅台  319.0  1583.28
# 1     SH600036   招商银行  213.0    45.07
# 2     SH600900   长江电力  207.0    27.74
# 3     SH600887   伊利股份  206.0    28.00
# 4     SH601318   中国平安  201.0    52.13
# ...        ...    ...    ...      ...
# 5482  SH603722    阿科力    0.0    42.50
# 5483  SZ300906    日月明    0.0    24.52
# 5484  SZ002259   ST升达    0.0     2.36
# 5485  SH688613   奥精医疗    0.0    15.89
# 5486  SZ301629  N矽电股份    NaN   161.35
#
# [5487 rows x 4 columns]

# %% [markdown]
# ### 股票热度-问财

# %%
import akshare as ak

stock_hot_rank_wc_df = ak.stock_hot_rank_wc(date="20250324")
stock_hot_rank_wc_df
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#         序号    股票代码  股票简称     现价    涨跌幅       个股热度     个股热度排名      排名日期
# 0        1  600580  卧龙电驱  29.37  10.00  5386605.5     1/5410  20250324
# 1        2  002724   海洋王   9.33  10.02  5172583.5     2/5410  20250324
# 2        3  601890  亚星锚链  11.42  10.02  5076415.0     3/5410  20250324
# 3        4  002204  大连重工   7.70  10.00  4557361.0     4/5410  20250324
# 4        5  002553  南方精工  23.70  -7.60  4263565.0     5/5410  20250324
# ...    ...     ...   ...    ...    ...        ...        ...       ...
# 4995  4996  001223  欧克科技  51.06  -3.97     7542.0  4996/5410  20250324
# 4996  4997  688328   深科达  15.46  -5.33     7535.5  4997/5410  20250324
# 4997  4998  600113  浙江东日  13.19  -0.68     7530.5  4998/5410  20250324
# 4998  4999  870508  丰安股份  16.87  -1.58     7528.5  4999/5410  20250324
# 4999  5000  688357  建龙微纳  26.66  -4.03     7525.5  5000/5410  20250324
#
# [5000 rows x 8 columns]

# %% [markdown]
# ### 股票热度-东财

# %% [markdown]
# #### 人气榜-A股

# %%
import akshare as ak

stock_hot_rank_em_df = ak.stock_hot_rank_em()
stock_hot_rank_em_df
# Out:
#     当前排名        代码  股票名称     最新价       涨跌额    涨跌幅
# 0      1  SH600320  振华重工    5.41  0.538836   9.96
# 1      2  SZ002204  大连重工    7.70  0.770000  10.00
# 2      3  SH601890  亚星锚链   11.42  1.144284  10.02
# 3      4  SZ002681  奋达科技    9.13  0.913000  10.00
# 4      5  SZ000678  襄阳轴承   15.31 -1.529469  -9.99
# ..   ...       ...   ...     ...       ...    ...
# 95    96  SZ000039  中集集团    9.89  0.341205   3.45
# 96    97  SH601226  华电科工    8.35  0.824145   9.87
# 97    98  SZ002427  尤夫股份    4.76  0.472668   9.93
# 98    99  SH600979  广安爱众    6.79  0.216601   3.19
# 99   100  SZ002594   比亚迪  374.98  2.999840   0.80
#
# [100 rows x 6 columns]

# %% [markdown]
# #### 飙升榜-A股

# %%
import akshare as ak

stock_hot_up_em_df = ak.stock_hot_up_em()
stock_hot_up_em_df
# Out:
#     排名较昨日变动  当前排名        代码  股票名称    最新价       涨跌额    涨跌幅
# 0      4921    31  SZ301025  读客文化  10.94  2.183624  19.96
# 1      4490   425  SZ300702  天宇股份  19.94  1.906264   9.56
# 2      4154   131  SH603999  读者传媒   6.89  0.693134  10.06
# 3      4154   752  SH601999  出版传媒   6.80  0.216920   3.19
# 4      4105   501  SZ871634   新威凌  30.39  4.175586  13.74
# ..      ...   ...       ...   ...    ...       ...    ...
# 95     1846  2131  SH603330  天洋新材   8.42  0.387320   4.60
# 96     1843  2105  SH601021  春秋航空  52.64  1.268624   2.41
# 97     1839  1794  SH600640  国脉文化  12.46 -0.118370  -0.95
# 98     1836   991  SZ300054  鼎龙股份  28.33  1.005715   3.55
# 99     1832  3131  SZ301188  力诺药包  17.06  0.368496   2.16
#
# [100 rows x 7 columns]

# %% [markdown]
# ### 个股人气榜-实时变动

# %%
import akshare as ak

stock_hot_rank_detail_realtime_em_df = ak.stock_hot_rank_detail_realtime_em(symbol="SZ000665")
stock_hot_rank_detail_realtime_em_df
# Out:
#                      时间   排名
# 0   2025-03-24 00:00:00  383
# 1   2025-03-24 00:10:00  385
# 2   2025-03-24 00:20:00  385
# 3   2025-03-24 00:30:00  384
# 4   2025-03-24 00:40:00  383
# ..                  ...  ...
# 84  2025-03-24 14:00:00  290
# 85  2025-03-24 14:10:00  294
# 86  2025-03-24 14:20:00  294
# 87  2025-03-24 14:30:00  295
# 88  2025-03-24 14:40:00  298
#
# [89 rows x 2 columns]

# %% [markdown]
# ### 热门关键词

# %%
import akshare as ak

stock_hot_keyword_em_df = ak.stock_hot_keyword_em(symbol="SZ000665")
stock_hot_keyword_em_df
# Out:
#                      时间      股票代码   概念名称    概念代码    热度
# 0   2025-03-24 14:00:00  SZ000665   算力概念  BK1134  1956
# 1   2025-03-24 14:00:00  SZ000665     广电  BK0904   783
# 2   2025-03-24 14:00:00  SZ000665   5G概念  BK0714    65
# 3   2025-03-24 14:00:00  SZ000665  元宇宙概念  BK1009    51
# 4   2025-03-24 14:00:00  SZ000665    云计算  BK0579    42
# 5   2025-03-24 14:00:00  SZ000665   国企改革  BK0683    38
# 6   2025-03-24 14:00:00  SZ000665   彩票概念  BK0671    11
# 7   2025-03-24 14:00:00  SZ000665   华为概念  BK0854     8
# 8   2025-03-24 14:00:00  SZ000665   超清视频  BK0859     5
# 9   2025-03-24 14:00:00  SZ000665   虚拟现实  BK0722     4
# 10  2025-03-24 14:00:00  SZ000665   预亏预减  BK0570     4
# 11  2025-03-24 14:00:00  SZ000665   智慧城市  BK0628     2

# %%
import akshare as ak

stock_hot_keyword_em_df = ak.stock_hot_keyword_em(symbol="SZ002292")
stock_hot_keyword_em_df
# Out:
#                      时间      股票代码   概念名称    概念代码   热度
# 0   2025-03-24 14:00:00  SZ002292   婴童概念  BK0664  209
# 1   2025-03-24 14:00:00  SZ002292   影视概念  BK0847  130
# 2   2025-03-24 14:00:00  SZ002292   人工智能  BK0800   59
# 3   2025-03-24 14:00:00  SZ002292   盲盒经济  BK0954   41
# 4   2025-03-24 14:00:00  SZ002292  机器人概念  BK1090   34
# 5   2025-03-24 14:00:00  SZ002292  元宇宙概念  BK1009   26
# 6   2025-03-24 14:00:00  SZ002292   虚拟现实  BK0722   26
# 7   2025-03-24 14:00:00  SZ002292   跨境电商  BK1115   12
# 8   2025-03-24 14:00:00  SZ002292   电商概念  BK0665    4
# 9   2025-03-24 14:00:00  SZ002292   预亏预减  BK0570    4
# 10  2025-03-24 14:00:00  SZ002292  NFT概念  BK0997    3
# 11  2025-03-24 14:00:00  SZ002292   手游概念  BK0642    2
# 12  2025-03-24 14:00:00  SZ002292   网络游戏  BK0509    1
# 13  2025-03-24 14:00:00  SZ002292   股权激励  BK0567    1

# %% [markdown]
# ### 热搜股票

# %%
import akshare as ak

stock_hot_search_baidu_df = ak.stock_hot_search_baidu(symbol="A股", date="20250324", time="今日")
stock_hot_search_baidu_df
# Out:
#       股票名称       涨跌幅  所属板块名称    市场代码       现价 市场缩写  排名变化  市场     综合热度
# 0     岩山科技    +0.16%   IT服务Ⅱ  002195     6.26   SZ     0  ab  1240968
# 1     巨轮智能    -2.07%    专用设备  002031     9.48   SZ    49  ab  1006445
# 2     巨力索具    -0.16%    通用设备  002342     6.38   SZ    13  ab   957515
# 3     浙大网新    -9.89%   IT服务Ⅱ  600797    12.75   SH     6  ab   931235
# 4   *ST东方     -5.33%     贸易Ⅱ  600811     0.71   SH     0  ab   890929
# 5     四川长虹    -0.09%    黑色家电  600839    11.12   SH    38  ab   779158
# 6     大连重工   +10.00%    专用设备  002204     7.70   SZ     0  ab   755720
# 7     拓维信息    -5.12%    软件开发  002261    30.40   SZ    59  ab   725074
# 8     利欧股份    -2.53%    通用设备  002131     3.86   SZ    12  ab   684349
# 9     卧龙电驱   +10.00%     电机Ⅱ  600580    29.37   SH     0  ab   644433
# 10    亚星锚链   +10.02%   航海装备Ⅱ  601890    11.42   SH    73  ab   630108
# 11    天海防务    +9.35%   航海装备Ⅱ  300008     7.60   SZ   -10  ab   625006
# 12    振华重工    +9.96%    专用设备  600320     5.41   SH     0  ab   599529
# 13    万马股份    -4.66%    电网设备  002276    16.38   SZ    18  ab   592741
# 14    中信重工   +10.08%    专用设备  601608     5.79   SH    65  ab   573775
# 15    襄阳轴承    -9.99%   汽车零部件  000678    15.31   SZ     0  ab   570615
# 16     N矽电  +202.22%     半导体  301629   158.00          0  ab   562247
# 17    东方海洋    -6.38%    医疗器械  002086     3.52   SZ   -12  ab   533295
# 18    海南华铁    +2.80%    多元金融  603300    11.00   SH    17  ab   499954
# 19    紫金矿业    +2.90%    工业金属  601899    18.08   SH    22  ab   498773
# 20    南方精工    -9.94%   汽车零部件  002553    23.10   SZ     0  ab   497156
# 21    大位科技   -10.03%   IT服务Ⅱ  600589     7.89   SH    11  ab   491739
# 22     比亚迪    +0.82%     乘用车  002594   375.06   SZ     0  ab   490795
# 23    三维通信     0.00%    通信服务  002115     9.38   SZ    59  ab   462895
# 24    永鼎股份    +6.15%    通信设备  600105     6.56   SH    41  ab   458129
# 25     欧菲光    -2.29%   光学光电子  002456    12.81   SZ    13  ab   453911
# 26    北方铜业   +10.05%    工业金属  000737    11.17   SZ     0  ab   452442
# 27    杭钢股份    -6.28%      普钢  600126    11.20   SH    -3  ab   452398
# 28    格力电器    +2.77%    白色家电  000651    44.95   SZ     0  ab   446221
# 29   中毅达     +10.05%    化学原料  600610     8.76   SH     0  ab   442266
# 30    中国联通    -0.35%    通信服务  600050     5.68   SH   -26  ab   440976
# 31    国脉科技   -10.01%      教育  002093    12.86   SZ    67  ab   438723
# 32     海兰信    +5.04%   航海装备Ⅱ  300065    20.41   SZ     1  ab   420676
# 33    神州信息   -10.03%   IT服务Ⅱ  000555    14.36   SZ     0  ab   419161
# 34    中远海控    +2.31%    航运港口  601919    14.59   SH     0  ab   405182
# 35    华培动力    -3.31%   汽车零部件  603121    19.29   SH     0  ab   401344
# 36    泰豪科技     0.00%   军工电子Ⅱ  600590     0.00   SH     0  ab   400946
# 37    浙文互联   -10.01%    广告营销  600986     9.26   SH    12  ab   388500
# 38    中国重工    +0.67%   航海装备Ⅱ  601989     4.54   SH   -30  ab   383844
# 39    中兴通讯    -0.66%    通信设备  000063    34.88   SZ     0  ab   382190
# 40    东方精工    -7.21%    专用设备  002611    12.48   SZ    21  ab   381711
# 41    神开股份    -5.40%    专用设备  002278    10.68   SZ     0  ab   373526
# 42    福日电子    -1.29%    消费电子  600203     9.93   SH     0  ab   372024
# 43    方正电机    -9.96%     电机Ⅱ  002196    10.22   SZ     0  ab   371974
# 44   三六零      +1.94%    软件开发  601360    11.06   SH     0  ab   371812
# 45    莲花控股    -6.78%  调味发酵品Ⅱ  600186     6.32   SH    35  ab   371505
# 46    贵州茅台    +0.68%     白酒Ⅱ  600519  1584.44   SH     0  ab   369140
# 47    方正科技    +0.19%      元件  600601     5.31   SH    38  ab   369113
# 48   赛力斯      +0.06%     乘用车  601127   124.45   SH     0  ab   368666
# 49    东华软件    -3.39%   IT服务Ⅱ  002065    10.83   SZ    44  ab   367894

# %%
import akshare as ak

stock_hot_search_baidu_df = ak.stock_hot_search_baidu(symbol="A股", date="20250324", time="1小时")
stock_hot_search_baidu_df
# Out:
#       股票名称       涨跌幅   所属板块名称    市场代码      现价 市场缩写  排名变化  市场    综合热度
# 0     岩山科技    +0.64%    IT服务Ⅱ  002195    6.29   SZ     2  ab  160991
# 1     奋达科技   +10.00%     消费电子  002681    9.13   SZ     0  ab  140435
# 2     大连重工   +10.00%     专用设备  002204    7.70   SZ     1  ab  134557
# 3     浙大网新    -9.89%    IT服务Ⅱ  600797   12.75   SH     3  ab  120148
# 4     卧龙电驱   +10.00%      电机Ⅱ  600580   29.37   SH    -4  ab  116293
# 5     巨轮智能    -2.17%     专用设备  002031    9.47   SZ     0  ab  110351
# 6     天海防务    +9.21%    航海装备Ⅱ  300008    7.59   SZ     0  ab   88934
# 7     亚星锚链   +10.02%    航海装备Ⅱ  601890   11.42   SH     0  ab   88933
# 8     中信重工   +10.08%     专用设备  601608    5.79   SH     0  ab   87614
# 9     四川长虹    +0.18%     黑色家电  600839   11.15   SH    -5  ab   85127
# 10     N矽电  +202.08%      半导体  301629  157.93          0  ab   83170
# 11    利欧股份    -2.27%     通用设备  002131    3.87   SZ    -3  ab   81279
# 12    华培动力    -3.01%    汽车零部件  603121   19.35   SH     0  ab   80277
# 13    巨力索具    -1.72%     通用设备  002342    6.28   SZ    -6  ab   75262
# 14    拓维信息    -5.12%     软件开发  002261   30.40   SZ    -5  ab   68997
# 15    中兴通讯    -0.66%     通信设备  000063   34.88   SZ     0  ab   67096
# 16     海兰信    +6.02%    航海装备Ⅱ  300065   20.60   SZ     0  ab   64664
# 17    永鼎股份    +6.47%     通信设备  600105    6.58   SH     0  ab   63100
# 18    东方海洋    -6.65%     医疗器械  002086    3.51   SZ     0  ab   61184
# 19    佛山照明   +10.01%    照明设备Ⅱ  000541    8.57   SZ     0  ab   60055
# 20    南方精工    -9.98%    汽车零部件  002553   23.09   SZ     0  ab   59067
# 21    明星电力    +6.70%       电力  600101   11.62   SH     0  ab   58636
# 22    工商银行    +1.18%  国有大型银行Ⅱ  601398    6.84   SH     0  ab   58278
# 23    洛阳钼业    +4.97%     工业金属  603993    8.02   SH     0  ab   58162
# 24    中国联通    -0.35%     通信服务  600050    5.68   SH     0  ab   57936
# 25    海默科技    +8.55%     专用设备  300084   10.41   SZ     0  ab   57281
# 26    东方财富    -0.09%      证券Ⅱ  300059   23.25   SZ     0  ab   57263
# 27    海南华铁    +2.71%     多元金融  603300   10.99   SH     0  ab   55838
# 28    北方铜业   +10.05%     工业金属  000737   11.17   SZ     0  ab   55300
# 29    浪潮信息    +1.70%    计算机设备  000977   57.59   SZ     0  ab   55072
# 30    三维通信    +1.17%     通信服务  002115    9.49   SZ     0  ab   54958
# 31     比亚迪    +0.90%      乘用车  002594  375.35   SZ     0  ab   53705
# 32    神开股份    -5.93%     专用设备  002278   10.62   SZ     0  ab   52366
# 33     海洋王   +10.02%    照明设备Ⅱ  002724    9.33   SZ     0  ab   52181
# 34    杭钢股份    -6.53%       普钢  600126   11.17   SH     0  ab   49333
# 35    万马股份    -5.06%     电网设备  002276   16.31   SZ     0  ab   48693
# 36    东方精工    -7.21%     专用设备  002611   12.48   SZ     0  ab   48593
# 37    振华重工    +9.96%     专用设备  600320    5.41   SH     0  ab   48417
# 38    浙文互联   -10.01%     广告营销  600986    9.26   SH     0  ab   48366
# 39  *ST东方     -5.33%      贸易Ⅱ  600811    0.71   SH     0  ab   47829
# 40    莲花控股    -6.78%   调味发酵品Ⅱ  600186    6.32   SH     0  ab   47393
# 41    胜利精密    -3.51%     消费电子  002426    3.57   SZ     0  ab   46826
# 42    上海电气    -1.89%  其他电源设备Ⅱ  601727    7.79   SH     0  ab   46498
# 43    杭齿前进    +3.05%     通用设备  601177   20.26   SH     0  ab   46460
# 44    紫金矿业    +2.85%     工业金属  601899   18.07   SH     0  ab   45661
# 45    大位科技   -10.03%    IT服务Ⅱ  600589    7.89   SH     0  ab   45638
# 46    汇洲智能    -4.80%     通用设备  002122    4.76   SZ     0  ab   45311
# 47    农业银行    +0.98%  国有大型银行Ⅱ  601288    5.14   SH     0  ab   44831
# 48    永泰能源    -0.67%     煤炭开采  600157    1.48   SH     0  ab   44749
# 49     张家界   +10.04%    旅游及景区  000430    8.11   SZ     0  ab   44653

# %% [markdown]
# ### 相关股票

# %%
import akshare as ak

stock_hot_rank_relate_em_df = ak.stock_hot_rank_relate_em(symbol="SZ000665")
stock_hot_rank_relate_em_df
# Out:
#                     时间      股票代码    相关股票代码   涨跌幅
# 0  2025-03-24 13:00:00  SZ000665  SZ000678  8.40
# 1  2025-03-24 13:00:00  SZ000665  SH600797  6.10
# 2  2025-03-24 13:00:00  SZ000665  SZ002195  4.95
# 3  2025-03-24 13:00:00  SZ000665  SZ002093  4.90
# 4  2025-03-24 13:00:00  SZ000665  SZ002342  4.85
# 5  2025-03-24 13:00:00  SZ000665  SH600589  4.82
# 6  2025-03-24 13:00:00  SZ000665  SH600126  4.23
# 7  2025-03-24 13:00:00  SZ000665  SZ002553  4.04
# 8  2025-03-24 13:00:00  SZ000665  SZ002276  3.88
# 9  2025-03-24 13:00:00  SZ000665  SZ002261  3.49

# %% [markdown]
# ## 盘口异动

# %%
import akshare as ak

stock_changes_em_df = ak.stock_changes_em(symbol="大笔买入")
stock_changes_em_df
# Out:
#             时间      代码    名称    板块                        相关信息
# 0     14:55:51  002842  翔鹭钨业  大笔买入     235400,7.12000,0.002813
# 1     14:55:47  831175  派诺科技  大笔买入     50000,23.30000,0.038938
# 2     14:55:27  837006  晟楠科技  大笔买入     43381,27.82000,0.040793
# 3     14:55:04  301289  国缆检测  大笔买入     30500,54.66000,0.040137
# 4     14:54:34  301161  唯万密封  大笔买入     65400,26.53000,0.039922
# ...        ...     ...   ...   ...                         ...
# 1758  09:30:00  600318  新力金融  大笔买入     752400,9.20000,0.023359
# 1759  09:30:00  601890  亚星锚链  大笔买入  12064100,10.97000,0.069364
# 1760  09:30:00  600101  明星电力  大笔买入   586600,10.79000,-0.009183
# 1761  09:30:00  605199   葫芦娃  大笔买入   727600,16.43000,-0.040612
# 1762  09:30:00  603131  上海沪工  大笔买入    415800,21.21000,0.024578
#
# [1763 rows x 5 columns]

# %% [markdown]
# ## 板块异动详情

# %%
import akshare as ak

stock_board_change_em_df = ak.stock_board_change_em()
stock_board_change_em_df
# Out:
#        板块名称   涨跌幅         主力净流入  板块异动总次数 板块异动最频繁个股及所属类型-股票代码  \
# 0      融资融券 -0.99 -5.087980e+06     8361              301079
# 1      预盈预增 -1.58 -1.689833e+06     3922              002165
# 2      创业板综 -2.18 -2.347394e+06     3857              301079
# 3      专精特新 -1.46 -1.265536e+06     3707              301079
# 4      预亏预减 -2.45 -1.739293e+06     3583              002115
# ..      ...   ...           ...      ...                 ...
# 567     GDR -0.23  7.834144e+02        3              601615
# 568    肝素概念 -0.74 -5.175838e+03        3              600062
# 569  第四代半导体 -0.13  1.264386e+03        3              601179
# 570  光伏高速公路 -0.72 -2.380631e+03        1              300365
# 571  科创板做市商  0.05 -2.558186e+04        1              600030
#
#     板块异动最频繁个股及所属类型-股票名称 板块异动最频繁个股及所属类型-买卖方向  \
# 0                  邵阳液压                大笔买入
# 1                 红 宝 丽                大笔买入
# 2                  邵阳液压                大笔买入
# 3                  邵阳液压                大笔买入
# 4                  三维通信                大笔买入
# ..                  ...                 ...
# 567                明阳智能                大笔卖出
# 568                华润双鹤                大笔卖出
# 569                中国西电                大笔卖出
# 570                恒华科技                大笔买入
# 571                中信证券                大笔卖出
#
#                                        板块具体异动类型列表及出现次数
# 0    [{'t': 8193, 'ct': 1132}, {'t': 8194, 'ct': 10...
# 1    [{'t': 8193, 'ct': 415}, {'t': 8220, 'ct': 379...
# 2    [{'t': 8193, 'ct': 744}, {'t': 8194, 'ct': 642...
# 3    [{'t': 8193, 'ct': 666}, {'t': 8194, 'ct': 666...
# 4    [{'t': 8220, 'ct': 439}, {'t': 8194, 'ct': 383...
# ..                                                 ...
# 567  [{'t': 64, 'ct': 1}, {'t': 8203, 'ct': 1}, {'t...
# 568  [{'t': 64, 'ct': 1}, {'t': 8202, 'ct': 1}, {'t...
# 569        [{'t': 128, 'ct': 2}, {'t': 8214, 'ct': 1}]
# 570                             [{'t': 8216, 'ct': 1}]
# 571                               [{'t': 64, 'ct': 1}]
#
# [572 rows x 8 columns]

# %% [markdown]
# ## 涨停板行情

# %% [markdown]
# ### 涨停股池

# %%
import akshare as ak

stock_zt_pool_em_df = ak.stock_zt_pool_em(date='20250324')
stock_zt_pool_em_df
# Out:
#     序号      代码    名称        涨跌幅    最新价         成交额          流通市值  \
# 0    1  001202  炬申股份  10.027101  20.30    24277805  1.835945e+09
# 1    2  002204  大连重工  10.000000   7.70  2732511104  1.487155e+10
# 2    3  002300  太阳电缆   9.952607   6.96    62802189  5.027034e+09
# 3    4  002767  先锋电子   9.994509  20.03    98292218  2.607552e+09
# 4    5  601608  中信重工  10.076046   5.79  3370797040  2.634779e+10
# 5    6  600320  振华重工   9.959350   5.41   508420704  1.797201e+10
# 6    7  688178   万德斯  19.976566  20.48    33261609  1.740756e+09
# 7    8  603280  南方路机  10.000000  30.80   177117568  8.606033e+08
# 8    9  601890  亚星锚链  10.019268  11.42  2908288224  1.095635e+10
# 9   10  002724   海洋王  10.023585   9.33  1031519424  5.334573e+09
# 10  11  002861  瀛通通讯  10.028248  15.58   208240202  2.339623e+09
# 11  12  603949  雪龙集团   9.995307  23.44   595748560  4.927212e+09
# 12  13  603359  东珠生态  10.027855   7.90   889300704  3.524158e+09
# 13  14  600882  妙可蓝多   9.989539  21.03   532734400  1.076849e+10
# 14  15  002681  奋达科技  10.000000   9.13  3158879216  1.409156e+10
# 15  16  301055   张小泉  19.974794  19.04   156812415  2.970240e+09
# 16  17  000888  峨眉山Ａ  10.014620  15.05   488596704  7.930042e+09
# 17  18  603011  合锻智能  10.010764  10.22   513622336  5.052916e+09
# 18  19  000430   张家界  10.040706   8.11   355701200  2.690402e+09
# 19  20  000558  天府文旅   9.941521   3.76   948031648  4.845454e+09
# 20  21  002427  尤夫股份   9.930716   4.76   189872968  4.690631e+09
# 21  22  600421  华嵘控股  10.015898   6.92    53875153  1.353552e+09
# 22  23  603908   牧高笛   9.983897  27.32   158634459  2.550759e+09
# 23  24  003039  顺控发展  10.015408  14.28   146361240  8.818167e+09
# 24  25  000601  韶能股份   9.963099   5.96   874145424  6.439542e+09
# 25  26  603072  天和磁材  10.004904  44.86   625395472  2.904489e+09
# 26  27  002735  王子新材   9.958072  10.49   437893568  2.943450e+09
# 27  28  603693  江苏新能  10.027348  12.07   462998608  1.076011e+10
# 28  29  605081   太和水  10.048309  11.39    64648145  1.289884e+09
# 29  30  300697  电工合金  20.000000  17.34   736414976  4.418232e+09
# 30  31  000737  北方铜业  10.049261  11.17  2498960384  1.979625e+10
# 31  32  600610   中毅达  10.050251   8.76   918553792  6.208446e+09
# 32  33  600593  大连圣亚   9.992887  30.93   525015536  3.983784e+09
# 33  34  000422  湖北宜化  10.000000  14.74  1605044112  1.559223e+10
# 34  35  003033  征和工业  10.010173  54.07   394240416  4.357941e+09
# 35  36  002391  长青股份   9.961685   5.74   216918968  2.664053e+09
# 36  37  002682  龙洲股份   9.939148   5.42   504030144  3.047992e+09
# 37  38  600470  六国化工   9.933775   6.64   828155184  3.463424e+09
# 38  39  301025  读客文化  19.956141  10.94   397457312  2.847228e+09
# 39  40  603999  读者传媒  10.063898   6.89   387044768  3.968640e+09
# 40  41  002630  华西能源   9.935205   5.09   652008976  5.393815e+09
# 41  42  603688  石英股份  10.000000  31.46  1047212752  1.704120e+10
# 42  43  605069  正和生态  10.000000  10.67   293819536  8.980008e+08
# 43  44  000541  佛山照明  10.012836   8.57  1574203696  1.014463e+10
# 44  45  834639  晨光电缆  29.916567  10.90   448028640  1.277653e+09
# 45  46  600580  卧龙电驱  10.000000  29.37  6342639360  3.825803e+10
# 46  47  301079  邵阳液压  19.993118  34.87  1403198560  2.403653e+09
# 47  48  002667  威领股份  10.000000  11.11   282157472  2.622908e+09
# 48  49  603090  宏盛股份  10.000000  25.19   258271414  2.519000e+09
#
#              总市值        换手率       封板资金  首次封板时间  最后封板时间  炸板次数 涨停统计  连板数  所属行业
# 0   2.614640e+09   1.322360  439487874  092500  092500     0  5/3    2  物流行业
# 1   1.487155e+10  18.402817  102379169  092500  141612    12  4/4    4  工程机械
# 2   5.027443e+09   1.249289  213165987  092500  092500     0  2/2    2  电网设备
# 3   3.004500e+09   3.769521   90150022  092500  092500     0  2/2    2  仪器仪表
# 4   2.651561e+10  13.096022   18040482  092501  144952     3  2/2    2  专用设备
# 5   2.850179e+10   2.828959  254058739  092502  092502     0  3/3    3  专用设备
# 6   1.743558e+09   1.910757  110460989  092504  092504     0  1/1    1  环保行业
# 7   3.338925e+09  20.662121   65151886  093036  093036     0  2/2    2  专用设备
# 8   1.095635e+10  27.224251   33215252  093051  144309     3  3/3    3  船舶制造
# 9   7.198076e+09  21.523695   37883905  093054  143533     0  8/6    1  电子元件
# 10  2.902304e+09   8.964098   83471408  093054  093054     0  1/1    1  消费电子
# 11  4.949044e+09  13.176610   43950937  093104  110140     2  5/5    5  汽车零部
# 12  3.524158e+09  25.612286   27004728  093114  144602     6  9/5    4  环保行业
# 13  1.076849e+10   4.976767    7525080  093203  131100     6  1/1    1  食品饮料
# 14  1.648336e+10  22.603699  138700558  093227  143133     1  1/1    1  消费电子
# 15  2.970240e+09   5.429107   35878842  093406  093406     0  1/1    1  通用设备
# 16  7.930042e+09   6.271787   66329865  093512  093512     0  1/1    1  旅游酒店
# 17  5.052915e+09  10.524150   54334630  093539  093539     0  1/1    1  专用设备
# 18  3.283071e+09  13.422076   52966920  093603  094200     3  1/1    1  旅游酒店
# 19  4.847482e+09  19.755754    1707423  093906  150000    14  1/1    1  旅游酒店
# 20  4.690660e+09   4.299670   46738449  093918  093918     0  2/2    2  化纤行业
# 21  1.353552e+09   4.060900   35211036  094138  094138     0  1/1    1  通用设备
# 22  2.550759e+09   6.333197   20730388  094256  094256     0  1/1    1  纺织服装
# 23  8.818168e+09   1.704461   38609507  094545  094545     0  1/1    1  公用事业
# 24  6.440088e+09  14.174935   76497559  095009  095515     1  4/3    1  电力行业
# 25  1.185560e+10  22.191864  119385289  095325  095325     0  4/2    1   小金属
# 26  4.007249e+09  15.116811   90332285  100133  100500     1  1/1    1  包装材料
# 27  1.076011e+10   4.407976   23737827  100642  143133     5  1/1    1  电力行业
# 28  1.289884e+09   5.176327   27116742  100702  100702     0  1/1    1  环保行业
# 29  5.770752e+09  17.270464   91811138  101221  101221     0  1/1    1  有色金属
# 30  2.127568e+10  13.002225   41711014  101321  142400     3  1/1    1  有色金属
# 31  9.384366e+09  15.324048   45487657  101429  112659     3  6/3    1  化学原料
# 32  3.983784e+09  13.539560   92073042  102615  102615     0  1/1    1  旅游酒店
# 33  1.596216e+10  10.544229   70844862  103115  103115     0  1/1    1  化肥行业
# 34  4.420222e+09   9.221272   20816950  103300  143142     1  1/1    1  汽车零部
# 35  3.728661e+09   8.394189   25103316  103812  103812     0  1/1    1  农药兽药
# 36  3.048038e+09  16.987942   67447293  103936  103936     0  1/1    1  物流行业
# 37  3.463424e+09  24.394957   21027552  104052  145143     5  1/1    1  化肥行业
# 38  4.379385e+09  14.721821   60634950  112827  132439     1  1/1    1  文化传媒
# 39  3.968640e+09  10.112093   42954878  112850  135705     1  1/1    1  文化传媒
# 40  6.010272e+09  12.606458  123617104  130000  130000     0  1/1    1  电源设备
# 41  1.704120e+10   6.260652   84871120  131610  131610     0  1/1    1  非金属材
# 42  2.258815e+09  34.411118   47051210  143036  143036     0  1/1    1  环保行业
# 43  1.316162e+10  16.458342  132479499  143503  143503     0  3/2    1  家电行业
# 44  2.197440e+09  38.566807   25646784  143655  143655     0  1/1    1  电网设备
# 45  3.825803e+10  17.439806  426376302  144920  144920     0  1/1    1    电机
# 46  3.812622e+09  64.551811   30821244  145015  145015     0  3/3    3  通用设备
# 47  2.692742e+09  11.305658   80536390  145148  145148     0  1/1    1  能源金属
# 48  2.519000e+09  10.927994    8017473  145244  145244     0  1/1    1  通用设备

# %% [markdown]
# ### 强势股池

# %%
import akshare as ak

stock_zt_pool_strong_em_df = ak.stock_zt_pool_strong_em(date='20250324')
stock_zt_pool_strong_em_df
# Out:
#       序号      代码    名称        涨跌幅    最新价    涨停价         成交额          流通市值  \
# 0      1  834639  晨光电缆  29.916567  10.90  10.90   448028640  1.277653e+09
# 1      2  831689   克莱特  25.583282  61.90  64.07   728852416  2.303337e+09
# 2      3  301079  邵阳液压  19.993118  34.87  34.87  1403198560  2.403653e+09
# 3      4  688178   万德斯  19.976566  20.48  20.48    33261609  1.740756e+09
# 4      5  301055   张小泉  19.974794  19.04  19.04   156812415  2.970240e+09
# ..   ...     ...   ...        ...    ...    ...         ...           ...
# 196  197  002903  宇环数控 -10.004066  22.13  27.05   135997702  2.303433e+09
# 197  198  002406  远东传动 -10.018382   9.79  11.97   594377312  5.895656e+09
# 198  199  000555  神州信息 -10.025063  14.36  17.56  2136489248  1.396208e+10
# 199  200  000595  宝塔实业 -10.038610   6.99   8.55   250996429  7.955059e+09
# 200  201  600243  青海华鼎 -10.075567   3.57   4.37   164870220  1.566694e+09
#
#               总市值        换手率        涨速 是否新高        量比 涨停统计          入选理由  所属行业
# 0    2.197440e+09  38.566807  0.000000    是  2.898718  1/1         60日新高  电网设备
# 1    4.543460e+09  37.950516  4.897475    是  1.021612  0/0         60日新高  通用设备
# 2    3.812622e+09  64.551811  0.000000    是  2.303669  3/3  60日新高且近期多次涨停  通用设备
# 3    1.743558e+09   1.910757  0.000000    是  1.080886  1/1         60日新高  环保行业
# 4    2.970240e+09   5.429107  0.000000    是  2.575956  1/1         60日新高  通用设备
# ..            ...        ...       ...  ...       ...  ...           ...   ...
# 196  3.447965e+09   5.904132  0.000000    否  0.315244  5/3        近期多次涨停  通用设备
# 197  7.148904e+09   9.866676  0.000000    否  0.388228  4/3        近期多次涨停  汽车零部
# 198  1.401212e+10  14.575680  0.000000    是  1.553865  2/1         60日新高  互联网服
# 199  7.959208e+09   3.114723  0.000000    否  0.488355  4/2        近期多次涨停  通用设备
# 200  1.566694e+09  10.517134  0.000000    否  0.862675  4/3        近期多次涨停  通用设备
#
# [201 rows x 16 columns]

# %% [markdown]
# ## 技术指标

# %% [markdown]
# ### 创新高

# %%
import akshare as ak

stock_rank_cxg_ths_df = ak.stock_rank_cxg_ths(symbol="创月新高")
stock_rank_cxg_ths_df
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
#       序号    股票代码  股票简称    涨跌幅   换手率    最新价   前期高点      前期高点日期
# 0      1  000006  深振业A   4.32  3.75   6.76   6.75  2025-03-11
# 1      2  000010  美丽生态   0.98  6.69   3.10   3.07  2025-03-20
# 2      3  000012   南玻A   0.80  1.20   5.05   5.02  2025-02-26
# 3      4  000035  中国天楹   1.63  2.40   4.98   4.91  2025-03-18
# 4      5  000039  中集集团   4.71  5.85   9.56   9.13  2025-03-20
# ..   ...     ...   ...    ...   ...    ...    ...         ...
# 401  402  605318   法狮龙   7.37  3.12  28.83  27.10  2025-03-17
# 402  403  605336  帅丰电器  10.00  8.08  22.33  20.52  2025-03-19
# 403  404  605377  华旺科技   0.31  1.38  12.99  12.95  2025-03-20
# 404  405  605577  龙版传媒   2.13  2.20  13.93  13.80  2025-02-21
# 405  406  605598  上海港湾   4.33  3.14  22.87  22.04  2025-03-14
#
# [406 rows x 8 columns]

# %% [markdown]
# ### 连续上涨

# %%
import akshare as ak

stock_rank_lxsz_ths_df = ak.stock_rank_lxsz_ths()
stock_rank_lxsz_ths_df
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#       序号    股票代码   股票简称    收盘价    最高价    最低价  连涨天数  连续涨跌幅   累计换手率     所属行业
# 0      1  600289  *ST信通   9.18   9.18   4.60    15  99.57   35.99     通信服务
# 1      2  600610    中毅达   7.96   8.00   4.04    10  97.52  142.24     化学原料
# 2      3  603828  ST柯利达   4.68   4.68   3.19    10  45.79   15.84     建筑装饰
# 3      4  003043   华亚智能  50.38  51.00  46.72     9   5.44   31.48      半导体
# 4      5  600968   海油发展   4.08   4.13   3.63     9  10.87    5.23  油气开采及服务
# ..   ...     ...    ...    ...    ...    ...   ...    ...     ...      ...
# 168  169  603218   日月股份  13.34  13.52  12.85     3   2.77    3.40     风电设备
# 169  170  603608  *ST天创   4.49   4.57   4.13     3   7.16    2.94     服装家纺
# 170  171  603637   镇海股份  10.02  10.30   9.68     3   1.83    9.70     建筑装饰
# 171  172  688191   智洋创新  25.74  26.20  24.01     3   1.74    7.86     电网设备
# 172  173  688206   概伦电子  25.03  25.50  20.92     3  18.96   28.25     软件开发
#
# [173 rows x 10 columns]

# %% [markdown]
# ### 量价齐升

# %%
import akshare as ak

stock_rank_ljqs_ths_df = ak.stock_rank_ljqs_ths()
stock_rank_ljqs_ths_df
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#       序号    股票代码  股票简称    最新价  量价齐升天数   阶段涨幅   累计换手率   所属行业
# 0      1  000601  韶能股份   5.96       5  41.90   48.53     电力
# 1      2  001239  永达股份  17.82       5  12.36   77.92   工程机械
# 2      3  001379  腾达科技  23.62       5   6.40   66.41   通用设备
# 3      4  300198  纳川股份   2.74       5  33.01   78.48   建筑材料
# 4      5  301298  东利机械  19.00       5  21.02  100.32  汽车零部件
# ..   ...     ...   ...    ...     ...    ...     ...    ...
# 791  792  688623  双元科技  57.12       1   0.99    1.40  自动化设备
# 792  793  688776  国光电气  79.70       1   9.48    3.87   军工电子
# 793  794  688788  科思科技  71.29       1   0.92    2.93   军工电子
# 794  795  688793   倍轻松  33.35       1  -7.10    8.03    小家电
# 795  796  688799  华纳药厂  39.67       1  -1.44    1.47   化学制药
#
# [796 rows x 8 columns]

# %%
import akshare as ak

stock_individual_fund_flow_df = ak.stock_individual_fund_flow(stock="002812", market="sz")
stock_individual_fund_flow_df
# Out:
#              日期    收盘价    涨跌幅     主力净流入-净额  主力净流入-净占比    超大单净流入-净额  \
# 0    2025-05-08  28.66   2.07   14389307.0       6.51    5542221.0
# 1    2025-05-09  28.50  -0.56  -16055519.0      -8.29  -10591729.0
# 2    2025-05-12  29.19   2.42   14656184.0       5.78   -3750133.0
# 3    2025-05-13  29.17  -0.07  -15503185.0      -6.41  -10291289.0
# 4    2025-05-14  29.25   0.27    3825065.0       2.03    -705941.0
# ..          ...    ...    ...          ...        ...          ...
# 115  2025-10-27  40.95   0.10   35585548.0       4.07   14177730.0
# 116  2025-10-28  40.97   0.05   55657048.0       6.34    3498921.0
# 117  2025-10-29  43.08   5.15  109378957.0       7.11   61360285.0
# 118  2025-10-30  44.11   2.39  132336535.0       6.07   72200359.0
# 119  2025-10-31  48.52  10.00  619024352.0      26.33  745943408.0
#
#      超大单净流入-净占比     大单净流入-净额  大单净流入-净占比     中单净流入-净额  中单净流入-净占比     小单净流入-净额  \
# 0          2.51    8847086.0       4.00    8701798.0       3.94  -23091106.0
# 1         -5.47   -5463790.0      -2.82   12721140.0       6.57    3334378.0
# 2         -1.48   18406317.0       7.26   -5340841.0      -2.11   -9315345.0
# 3         -4.25   -5211896.0      -2.15     192027.0       0.08   15311158.0
# 4         -0.37    4531006.0       2.40   -9352714.0      -4.96    5527648.0
# ..          ...          ...        ...          ...        ...          ...
# 115        1.62   21407818.0       2.45   13251648.0       1.52  -48837188.0
# 116        0.40   52158127.0       5.94   -4629168.0      -0.53  -51027896.0
# 117        3.99   48018672.0       3.12  -44255392.0      -2.88  -65123568.0
# 118        3.31   60136176.0       2.76  -17486016.0      -0.80 -114850528.0
# 119       31.73 -126919056.0      -5.40 -377049474.0     -16.04 -241974870.0
#
#      小单净流入-净占比
# 0       -10.44
# 1         1.72
# 2        -3.67
# 3         6.33
# 4         2.93
# ..         ...
# 115      -5.59
# 116      -5.82
# 117      -4.23
# 118      -5.27
# 119     -10.29
#
# [120 rows x 13 columns]

# %%
import akshare as ak

stock_individual_fund_flow_rank_df = ak.stock_individual_fund_flow_rank(indicator="今日")
stock_individual_fund_flow_rank_df
# Out:
#   0%|          | 0/53 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[17], line 3
#       1 import akshare as ak
# ----> 3 stock_individual_fund_flow_rank_df = ak.stock_individual_fund_flow_rank(indicator="今日")
#       4 stock_individual_fund_flow_rank_df
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/stock/stock_fund_em.py:173, in stock_individual_fund_flow_rank(indicator)
#     167 for page in tqdm(range(1, total_page + 1), leave=False):
#     168     params.update(
#     169         {
#     170             "pn": page,
#     171         }
#     172     )
# --> 173     r = requests.get(url, params=params, timeout=15)
#     174     data_json = r.json()
#     175     inner_temp_df = pd.DataFrame(data_json["data"]["diff"])
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)    678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# ### 行情报价
#
# 接口: stock_bid_ask_em
#
# 目标地址: https://quote.eastmoney.com/sz000001.html
#
# 描述: 东方财富-行情报价
#
# 限量: 单次返回指定股票的行情报价数据

# %%
import akshare as ak

stock_bid_ask_em_df = ak.stock_bid_ask_em(symbol="001239")
stock_bid_ask_em_df
# Out:
#           item        value
# 0       sell_5        15.71
# 1   sell_5_vol      1000.00
# 2       sell_4        15.70
# 3   sell_4_vol      1300.00
# 4       sell_3        15.67
# 5   sell_3_vol      6600.00
# 6       sell_2        15.66
# 7   sell_2_vol     16100.00
# 8       sell_1        15.65
# 9   sell_1_vol      4000.00
# 10       buy_1        15.64
# 11   buy_1_vol      6100.00
# 12       buy_2        15.63
# 13   buy_2_vol     11300.00
# 14       buy_3        15.62
# 15   buy_3_vol       400.00
# 16       buy_4        15.61
# 17   buy_4_vol      6700.00
# 18       buy_5        15.60
# 19   buy_5_vol     24000.00
# 20          最新        15.65
# 21          均价        15.86
# 22          涨幅        -3.40
# 23          涨跌        -0.55
# 24          总手     32756.00
# 25          金额  51961658.00
# 26          换手         2.87
# 27          量比         1.11
# 28          最高        16.20
# 29          最低        15.61
# 30          今开        16.07
# 31          昨收        16.20
# 32          涨停        17.82
# 33          跌停        14.58
# 34          外盘     13057.00
# 35          内盘     19699.00

# %% [markdown]
# ### 实时行情数据-新浪
#
# 接口: stock_zh_a_spot
#
# 目标地址: https://vip.stock.finance.sina.com.cn/mkt/#hs_a
#
# 描述: 新浪财经-沪深京 A 股数据, 重复运行本函数会被新浪暂时封 IP, 建议增加时间间隔
#
# 限量: 单次返回沪深京 A 股上市公司的实时行情数据

# %%
import akshare as ak

stock_zh_a_spot_df = ak.stock_zh_a_spot()
stock_zh_a_spot_df
# Out:
# Please wait for a moment:   0%|          | 0/69 [00:00<?, ?it/s]
#             代码     名称     最新价    涨跌额     涨跌幅      买入      卖出      昨收      今开  \
# 0     bj920000   安徽凤凰   19.35  -0.94  -4.633   19.34   19.35   20.29   20.00
# 1     bj920001   纬达光电   18.99  -0.92  -4.621   18.99   19.00   19.91   19.70
# 2     bj920002   万达轴承  104.69   2.29   2.236  104.69  104.70  102.40  102.00
# 3     bj920003   中诚咨询   33.70  -0.12  -0.355   33.69   33.70   33.82   33.50
# 4     bj920005  XD鼎佳精   42.52  -1.55  -3.517   42.51   42.52   44.07   44.29
# ...        ...    ...     ...    ...     ...     ...     ...     ...     ...
# 5446  sz301662   宏工科技  122.30 -19.78 -13.922  122.29  122.30  142.08  137.21
# 5447  sz301665   泰禾股份   30.21  -1.46  -4.610   30.21   30.22   31.67   31.60
# 5448  sz301668   昊创瑞通   49.05  -3.24  -6.196   49.05   49.06   52.29   51.72
# 5449  sz301678    新恒汇   62.30  -3.16  -4.827   62.30   62.36   65.46   64.29
# 5450  sz302132   中航成飞   79.80  -1.17  -1.445   79.79   79.80   80.97   80.01
#
#           最高      最低         成交量          成交额       时间戳
# 0      20.31   19.33   1407160.0   27617293.0  15:25:49
# 1      19.86   18.82   1647723.0   31587282.0  15:25:49
# 2     109.60  101.21   1641918.0  172920163.0  15:25:49
# 3      34.88   33.40   2246515.0   76435887.0  15:25:49
# 4      44.29   42.44    466085.0   20022359.0  15:25:49
# ...      ...     ...         ...          ...       ...
# 5446  140.80  122.18   2936584.0  376411042.0  15:25:15
# 5447   32.03   30.15   3698347.0  113373109.0  15:25:30
# 5448   52.05   49.01   2877234.0  143851918.0  15:25:45
# 5449   64.96   61.55   2966068.0  188116348.0  15:26:00
# 5450   82.48   79.50  10581693.0  854400303.0  15:25:15
#
# [5451 rows x 14 columns]

# %%
stock_zh_a_spot_df.to_csv("新浪实时行情数据stock_zh_a_spot_df_20251121.csv", index=False)

# %%
import akshare as ak

stock_zh_a_hist_tx_df = ak.stock_zh_a_hist_tx(symbol="sz000001", start_date="20200101", end_date="20251027", adjust="")
stock_zh_a_hist_tx_df
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#             date   open  close   high    low      amount
# 0     2020-01-02  16.65  16.87  16.95  16.55  1530231.87
# 1     2020-01-03  16.94  17.18  17.31  16.92  1116194.81
# 2     2020-01-06  17.01  17.07  17.34  16.91   862083.50
# 3     2020-01-07  17.13  17.15  17.28  16.95   728607.56
# 4     2020-01-08  17.00  16.66  17.05  16.63   847824.12
# ...          ...    ...    ...    ...    ...         ...
# 1403  2025-10-21  11.40  11.43  11.47  11.39   761165.00
# 1404  2025-10-22  11.40  11.52  11.54  11.40   833703.00
# 1405  2025-10-23  11.52  11.63  11.71  11.50  1373112.00
# 1406  2025-10-24  11.60  11.56  11.68  11.55   980475.00
# 1407  2025-10-27  11.54  11.52  11.61  11.44  1239485.00
#
# [1408 rows x 6 columns]

# %% [markdown]
# ### 历史分笔数据
#
# 腾讯财经
# 接口: stock_zh_a_tick_tx
#
# 目标地址: http://gu.qq.com/sz300494/gp/detail(示例)
#
# 描述: 每个交易日 16:00 提供当日数据; 如遇到数据缺失, 请使用 ak.stock_zh_a_tick_163() 接口(注意数据会有一定差异)
#
# 限量: 单次返回最近交易日的历史分笔行情数据

# %%
import akshare as ak

stock_zh_a_tick_tx_js_df = ak.stock_zh_a_tick_tx_js(symbol="sz000001")
stock_zh_a_tick_tx_js_df
# Out:
# /Users/zhengshuang/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/stock/stock_zh_a_tick_tx.py:27: UserWarning: 正在下载数据，请稍等
#   warnings.warn("正在下载数据，请稍等")
#           成交时间   成交价格  价格变动    成交量      成交金额   性质
# 0     09:25:00  11.80  0.00  21079  24873220   卖盘
# 1     09:30:00  11.82  0.02   1490   1759425   买盘
# 2     09:30:03  11.82  0.00   2985   3528317   买盘
# 3     09:30:06  11.83  0.01   2267   2682368   买盘
# 4     09:30:09  11.84  0.01   3951   4681751  中性盘
# ...        ...    ...   ...    ...       ...  ...
# 4601  14:56:51  11.67 -0.01     47     54874   卖盘
# 4602  14:56:54  11.67  0.00    116    135386   卖盘
# 4603  14:56:57  11.67  0.00    116    135422   卖盘
# 4604  14:57:00  11.67  0.00     39     45526   卖盘
# 4605  15:00:00  11.69  0.02  17456  20406415   卖盘
#
# [4606 rows x 6 columns]

# %%
stock_zh_a_tick_tx_js_df = ak.stock_zh_a_tick_tx_js(symbol="sh600257")
stock_zh_a_tick_tx_js_df
# Out:
# /Users/zhengshuang/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/stock/stock_zh_a_tick_tx.py:27: UserWarning: 正在下载数据，请稍等
#   warnings.warn("正在下载数据，请稍等")
#           成交时间  成交价格  价格变动    成交量      成交金额  性质
# 0     09:25:03  6.21  0.00  19922  12371562  卖盘
# 1     09:30:00  6.25  0.04    292    181474  买盘
# 2     09:30:03  6.21 -0.04   1654   1032061  卖盘
# 3     09:30:06  6.21  0.00   3146   1953891  卖盘
# 4     09:30:09  6.28  0.07   3285   2055308  买盘
# ...        ...   ...   ...    ...       ...  ..
# 4081  14:56:51  6.11  0.00    173    105714  卖盘
# 4082  14:56:54  6.11  0.00    381    232975  卖盘
# 4083  14:56:57  6.11  0.00    300    183320  卖盘
# 4084  14:57:00  6.11  0.00    146     89296  买盘
# 4085  15:00:03  6.13  0.02   8789   5387657  买盘
#
# [4086 rows x 6 columns]

# %% [markdown]
# ### 行情报价
#
# 接口: stock_bid_ask_em
#
# 目标地址: https://quote.eastmoney.com/sz000001.html
#
# 描述: 东方财富-行情报价
#
# 限量: 单次返回指定股票的行情报价数据

# %%
import akshare as ak

stock_bid_ask_em_df = ak.stock_bid_ask_em(symbol="000008")
stock_bid_ask_em_df
# Out:
#           item         value
# 0       sell_5  3.070000e+00
# 1   sell_5_vol  2.717000e+05
# 2       sell_4  3.060000e+00
# 3   sell_4_vol  7.750000e+04
# 4       sell_3  3.050000e+00
# 5   sell_3_vol  5.266000e+05
# 6       sell_2  3.040000e+00
# 7   sell_2_vol  2.654000e+05
# 8       sell_1  3.030000e+00
# 9   sell_1_vol  6.333000e+05
# 10       buy_1  3.020000e+00
# 11   buy_1_vol  1.634500e+06
# 12       buy_2  3.010000e+00
# 13   buy_2_vol  1.233200e+06
# 14       buy_3  3.000000e+00
# 15   buy_3_vol  1.383200e+06
# 16       buy_4  2.990000e+00
# 17   buy_4_vol  7.836000e+05
# 18       buy_5  2.980000e+00
# 19   buy_5_vol  3.230000e+05
# 20          最新  3.020000e+00
# 21          均价  3.070000e+00
# 22          涨幅 -3.820000e+00
# 23          涨跌 -1.200000e-01
# 24          总手  1.142596e+06
# 25          金额  3.503251e+08
# 26          换手  4.210000e+00
# 27          量比  8.000000e-01
# 28          最高  3.150000e+00
# 29          最低  3.010000e+00
# 30          今开  3.100000e+00
# 31          昨收  3.140000e+00
# 32          涨停  3.450000e+00
# 33          跌停  2.830000e+00
# 34          外盘  4.610520e+05
# 35          内盘  6.815450e+05

# %% [markdown]
# ### 实时行情数据-东财
#
# 沪深京 A 股
# 接口: stock_zh_a_spot_em
#
# 目标地址: https://quote.eastmoney.com/center/gridlist.html#hs_a_board
#
# 描述: 东方财富网-沪深京 A 股-实时行情数据

# %%
import akshare as ak

stock_zh_a_spot_em_df = ak.stock_zh_a_spot_em()
stock_zh_a_spot_em_df
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[22], line 3
#       1 import akshare as ak
# ----> 3 stock_zh_a_spot_em_df = ak.stock_zh_a_spot_em()
#       4 stock_zh_a_spot_em_df
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/stock_feature/stock_hist_em.py:36, in stock_zh_a_spot_em()
#      22 url = "https://82.push2.eastmoney.com/api/qt/clist/get"
#      23 params = {
#      24     "pn": "1",
#      25     "pz": "100",
#    (...)     34               "f20,f21,f23,f24,f25,f22,f11,f62,f128,f136,f115,f152",
#      35 }
# ---> 36 temp_df = fetch_paginated_data(url, params)
#      37 temp_df.columns = [
#      38     "index",
#      39     "_",
#    (...)     69     "-",
#      70 ]
#      71 temp_df.rename(columns={"index": "序号"}, inplace=True)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/utils/func.py:32, in fetch_paginated_data(url, base_params, timeout)
#      30 params = base_params.copy()
#      31 # 获取第一页数据，用于确定分页信息
# ---> 32 r = requests.get(url, params=params, timeout=timeout)
#      33 data_json = r.json()
#      34 # 计算分页信息
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)    678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
import akshare as ak

stock_sh_a_spot_em_df = ak.stock_sh_a_spot_em()
stock_sh_a_spot_em_df
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.7_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[23], line 3
#       1 import akshare as ak
# ----> 3 stock_sh_a_spot_em_df = ak.stock_sh_a_spot_em()
#       4 stock_sh_a_spot_em_df
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/stock_feature/stock_hist_em.py:145, in stock_sh_a_spot_em()
#     131 url = "https://82.push2.eastmoney.com/api/qt/clist/get"
#     132 params = {
#     133     "pn": "1",
#     134     "pz": "100",
#    (...)    143               "f24,f25,f22,f11,f62,f128,f136,f115,f152",
#     144 }
# --> 145 temp_df = fetch_paginated_data(url, params)
#     146 temp_df.columns = [
#     147     "序号",
#     148     "_",
#    (...)    178     "-",
#     179 ]
#     180 temp_df = temp_df[
#     181     [
#     182         "序号",
#    (...)    205     ]
#     206 ]
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/utils/func.py:32, in fetch_paginated_data(url, base_params, timeout)
#      30 params = base_params.copy()
#      31 # 获取第一页数据，用于确定分页信息
# ---> 32 r = requests.get(url, params=params, timeout=timeout)
#      33 data_json = r.json()
#      34 # 计算分页信息
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)    678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# ### 实时行情数据-雪球（无法获取到数据）
#
# 接口: stock_individual_spot_xq
#
# 目标地址: https://xueqiu.com/S/SH513520
#
# 描述: 雪球-行情中心-个股
#
# 限量: 单次获取指定 symbol 的最新行情数据

# %%
import akshare as ak

stock_individual_spot_xq_df = ak.stock_individual_spot_xq(symbol="SH603866")
stock_individual_spot_xq_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 3
#       1 import akshare as ak
# ----> 3 stock_individual_spot_xq_df = ak.stock_individual_spot_xq(symbol="SH603866")
#       4 stock_individual_spot_xq_df
#
# File ~/Library/Caches/pypoetry/virtualenvs/tracker-1jWEZn9S-py3.12/lib/python3.12/site-packages/akshare/stock/stock_xq.py:104, in stock_individual_spot_xq(symbol, token, timeout)
#      57 column_name_map = {
#      58     "acc_unit_nav": "累计净值",
#      59     "amount": "成交额",
#    (...)    101     "time": "时间",
#     102 }
#     103 json_data = r.json()
# --> 104 temp_df = pd.json_normalize(json_data["data"]["quote"])
#     105 temp_df.columns = [
#     106     *map(
#     107         lambda x: column_name_map[x] if x in column_name_map.keys() else x,
#     108         temp_df.columns,
#     109     )  # 由于传入的 symbol 可能是个股，可能是指数，也可能是基金，所以这里取列的最大公约数，没有数据的列内容为 None
#     110 ]
#     111 temp_df = temp_df[
#     112     list(
#     113         filter(
#    (...)    117     )
#     118 ]
#
# KeyError: 'data'

# %% [markdown]
# #### 日内分时数据-东财
# 接口: stock_intraday_em
#
# 目标地址: https://quote.eastmoney.com/f1.html?newcode=0.000001
#
# 描述: 东方财富-分时数据
#
# 限量: 单次返回指定股票最近一个交易日的分时数据, 包含盘前数据

# %%
import akshare as ak

stock_intraday_em_df = ak.stock_intraday_em(symbol="603877")
stock_intraday_em_df
# Out:
#             时间    成交价    手数 买卖盘性质
# 0     09:15:02  16.55    40   中性盘
# 1     09:15:05  16.37    83   中性盘
# 2     09:15:08  16.37   220   中性盘
# 3     09:15:11  16.49   388   中性盘
# 4     09:15:14  16.49   500   中性盘
# ...        ...    ...   ...   ...
# 3825  14:56:50  15.95    27    卖盘
# 3826  14:56:53  15.96    26    买盘
# 3827  14:56:56  15.95    11    卖盘
# 3828  14:56:59  15.95    33    卖盘
# 3829  15:00:00  15.95  3373    卖盘
#
# [3830 rows x 4 columns]

# %% [markdown]
# ### 股票列表-A股
#
# 接口: stock_info_a_code_name
#
# 目标地址: 沪深京三个交易所
#
# 描述: 沪深京 A 股股票代码和股票简称数据
#
# 限量: 单次获取所有 A 股股票代码和简称数据

# %%
import akshare as ak

stock_info_a_code_name_df = ak.stock_info_a_code_name()
stock_info_a_code_name_df
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
#         code   name
# 0     000001   平安银行
# 1     000002  万  科Ａ
# 2     000004  *ST国华
# 3     000006   深振业Ａ
# 4     000007    全新好
# ...      ...    ...
# 5447  920978   开特股份
# 5448  920981   晶赛科技
# 5449  920982   锦波生物
# 5450  920985   海泰新能
# 5451  920992   中科美菱
#
# [5452 rows x 2 columns]

# %% [markdown]
# ## 龙虎榜
# ### 龙虎榜-东财
# #### 营业部排行
# 接口: stock_lhb_yybph_em
#
# 目标地址: https://data.eastmoney.com/stock/yybph.html
#
# 描述: 东方财富网-数据中心-龙虎榜单-营业部排行
#
# 限量: 单次返回所有历史数据

# %%
import akshare as ak

stock_lhb_yybph_em_df = ak.stock_lhb_yybph_em(symbol="近一月")
stock_lhb_yybph_em_df
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#         序号                    营业部名称  上榜后1天-买入次数  上榜后1天-平均涨幅  上榜后1天-上涨概率  \
# 0        1           开源证券西安西大街证券营业部         301    1.238154   51.827243
# 1        2                    深股通专用         264    1.086831   53.030303
# 2        3       东方财富证券拉萨东环路第二证券营业部         223   -1.323351   43.049327
# 3        4                     国泰海通         218    0.043129   48.165138
# 4        5  高盛(中国)证券上海浦东新区世纪大道证券营业部         204    0.171199   47.549020
# ...    ...                      ...         ...         ...         ...
# 1053  1054           东北证券杭州教工路证券营业部           1   -2.126893    0.000000
# 1054  1055          国泰海通证券北京国贸证券营业部           1   -2.922374    0.000000
# 1055  1056                五矿证券河南分公司           1    4.983012  100.000000
# 1056  1057           平安证券东莞石竹路证券营业部           1    5.191996  100.000000
# 1057  1058       浙商证券成都高新区益州大道证券营业部           1   -9.996492    0.000000
#
#       上榜后2天-买入次数  上榜后2天-平均涨幅  上榜后2天-上涨概率  上榜后3天-买入次数  上榜后3天-平均涨幅  上榜后3天-上涨概率  \
# 0            287    1.746496   48.780488         271    2.373437   51.660517
# 1            256    1.464493   48.046875         244    1.679322   47.950820
# 2            209   -1.687938   38.755981         201   -2.004847   35.323383
# 3            213    0.085562   45.539906         210    0.065397   46.666667
# 4            197   -0.034964   40.101523         190   -0.200873   45.263158
# ...          ...         ...         ...         ...         ...         ...
# 1053           1    1.802451  100.000000           1    6.885364  100.000000
# 1054           1   -2.739726    0.000000           1  -10.730594    0.000000
# 1055           1   -0.283126    0.000000           1   -5.266138    0.000000
# 1056           1    1.784749  100.000000           1    0.054083  100.000000
# 1057           1  -17.151877    0.000000           1  -20.413890    0.000000
#
#       上榜后5天-买入次数  上榜后5天-平均涨幅  上榜后5天-上涨概率  上榜后10天-买入次数  上榜后10天-平均涨幅  \
# 0            238    1.456723   46.638655          176     4.654366
# 1            211    2.172982   51.658768          149     5.972381
# 2            174   -1.431525   36.206897          127    -0.137248
# 3            190    1.709913   52.631579          131     2.277480
# 4            170    1.096490   47.647059          115    -0.836208
# ...          ...         ...         ...          ...          ...
# 1053           0    0.000000    0.000000            0     0.000000
# 1054           1  -13.881279    0.000000            1    -8.812785
# 1055           0    0.000000    0.000000            0     0.000000
# 1056           1   -2.379665    0.000000            1    -4.651163
# 1057           1  -19.431778    0.000000            1   -16.274991
#
#       上榜后10天-上涨概率
# 0       49.431818
# 1       50.335570
# 2       40.157480
# 3       48.854962
# 4       36.521739
# ...           ...
# 1053     0.000000
# 1054     0.000000
# 1055     0.000000
# 1056     0.000000
# 1057     0.000000
#
# [1058 rows x 17 columns]

# %%
stock_lhb_yybph_em_df = ak.stock_lhb_yybph_em(symbol="近六月")
stock_lhb_yybph_em_df
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#         序号                营业部名称  上榜后1天-买入次数  上榜后1天-平均涨幅  上榜后1天-上涨概率  \
# 0        1   东方财富证券拉萨东环路第二证券营业部        1567   -1.428599   37.077218
# 1        2   东方财富证券拉萨团结路第一证券营业部        1429   -1.721764   34.919524
# 2        3                深股通专用        1428    0.908189   51.470588
# 3        4  东方财富证券拉萨金融城南环路证券营业部        1231   -1.505888   37.774167
# 4        5                 国泰海通        1217    0.260273   45.850452
# ...    ...                  ...         ...         ...         ...
# 3148  3149            渤海证券湖南分公司           1    3.428239  100.000000
# 3149  3150      信达证券厦门高林中路证券营业部           1    9.953162  100.000000
# 3150  3151          民生证券山东第二分公司           1   -5.822551    0.000000
# 3151  3152        招商证券天津鼓楼证券营业部           1   -4.736842    0.000000
# 3152  3153       招商证券郑州北龙湖证券营业部           1   -5.003014    0.000000
#
#       上榜后2天-买入次数  上榜后2天-平均涨幅  上榜后2天-上涨概率  上榜后3天-买入次数  上榜后3天-平均涨幅  上榜后3天-上涨概率  \
# 0           1551   -2.198894   31.528046        1541   -2.756973   30.629461
# 1           1408   -2.425122   32.244318        1396   -2.814694   30.802292
# 2           1420    0.911244   46.760563        1408    0.831565   46.235795
# 3           1215   -2.296541   31.769547        1206   -2.593412   31.674959
# 4           1212    0.471717   45.462046        1209    0.719291   47.146402
# ...          ...         ...         ...         ...         ...         ...
# 3148           1   10.691458  100.000000           1   13.015689  100.000000
# 3149           1   20.960187  100.000000           1   33.021077  100.000000
# 3150           1   -0.184843    0.000000           1    9.796673  100.000000
# 3151           1   -9.473684    0.000000           1  -14.210526    0.000000
# 3152           1   -8.981314    0.000000           1   -7.775769    0.000000
#
#       上榜后5天-买入次数  上榜后5天-平均涨幅  上榜后5天-上涨概率  上榜后10天-买入次数  上榜后10天-平均涨幅  \
# 0           1509   -3.471530   28.495693         1445    -3.912552
# 1           1365   -3.259573   30.183150         1315    -3.701231
# 2           1375    0.888994   42.472727         1313     1.960708
# 3           1182   -3.067883   29.949239         1132    -3.591791
# 4           1189    1.137952   45.920942         1130     1.719311
# ...          ...         ...         ...          ...          ...
# 3148           1    3.079605  100.000000            1   -11.446833
# 3149           1   14.754098  100.000000            1    16.861827
# 3150           1    3.216266  100.000000            1   -16.820702
# 3151           1  -22.631579    0.000000            1   -40.000000
# 3152           1  -15.732369    0.000000            1    -1.145268
#
#       上榜后10天-上涨概率
# 0       28.581315
# 1       29.049430
# 2       43.031226
# 3       28.533569
# 4       43.628319
# ...           ...
# 3148     0.000000
# 3149   100.000000
# 3150     0.000000
# 3151     0.000000
# 3152     0.000000
#
# [3153 rows x 17 columns]

# %% [markdown]
# ### 赚钱效应分析
#
# 接口: stock_market_activity_legu
#
# 目标地址: https://www.legulegu.com/stockdata/market-activity
#
# 描述: 乐咕乐股网-赚钱效应分析数据
#
# 限量: 单次返回当前赚钱效应分析数据

# %%
import akshare as ak

stock_market_activity_legu_df = ak.stock_market_activity_legu()
stock_market_activity_legu_df
# Out:
#         item                value
# 0         上涨                332.0
# 1         涨停                 33.0
# 2       真实涨停                 29.0
# 3   st st*涨停                  5.0
# 4         下跌               4812.0
# 5         跌停                107.0
# 6       真实跌停                 87.0
# 7   st st*跌停                 32.0
# 8         平盘                 17.0
# 9         停牌                  7.0
# 10       活跃度                6.42%
# 11      统计日期  2025-11-21 15:00:00

# %% [markdown]
# > 下一步可以考虑进行记录的数据
# > 1. 实时行情数据-新浪
# > 2. 行情报价-东财 stock_bid_ask_em
# > 3. 历史分笔数据-腾讯 stock_zh_a_tick_tx_js
# > 4. 涨跌股票数量，赚钱效应分析 stock_market_activity_legu
